# %%
import numpy as np
from scipy.optimize import fsolve
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# # No Cover

# %%
# --- Input Parameters ---
params = {
    "q_sun": 1000,         # Incident solar flux (W/m^2) minus reflective loss
    "ref_abs": 0.9645,               # Solar absorber's reflectance (3.55%)
    "condition": 'indoor',
    "T_amb_c": 25,        # Ambient air temperature (Celsius)
    "T_b_c": 30,          # Back wall temperature (Celsius), set to be 5C higher than ambient
    "v": 2.0,             # Wind speed (m/s)
    "a": 0.05,            # Device width (m)
    "b": 0.0035,          # Unit stage thickness (m)
    "t_ins": 0.01,        # Insulation thickness (m)
    "D_a": 3.0e-5,        # Diffusivity of vapor in air (m²/s)
    "k": 0.04,            # Thermal conductivity of insulation (W/mK)
    "k_air": 0.026,       # Thermal conductivity of air (W/mK)
    "Pr": 0.71,           # Prandtl number for air 
    "epsilon": 0.95,      # Emissivity of the solar absorber (CNT: 0.95, SSA: 0.03)
    "h_fg": 2357e3,       # Latent heat of vaporization (J/kg, converted from kJ/kg)
    "M_water": 0.018015,  # Molar mass of water (kg/mol)
    "R_gas": 8.314,       # Universal gas constant (J/(mol*K))
    "sigma": 5.67e-8      # Stefan-Boltzmann constant (W/m²K⁴)
}

# %%
# Obtain convective heat transfer coefficient (h_a)    
def get_air_properties(T_amb_c):
    T_amb_k = T_amb_c + 273.15
     # Density using ideal gas law at 1 atm (101325 Pa)
    P_atm = 101325  
    R_air = 287.05  # J/(kg·K) - specific gas constant for air
    rho = P_atm / (R_air * T_amb_k)  # kg/m³

    # Dynamic viscosity using Sutherland's formula
    T_ref = 273.15
    mu_ref = 1.716e-5  # Pa·s at T_ref       
    S = 110.4  # K (Sutherland constant for air)
    mu = mu_ref * (T_amb_k / T_ref)**1.5 * (T_ref + S) / (T_amb_k + S)  # Pa·s
    
    return rho, mu
    
def get_h_a_windy(T_amb_c, v, a):
    T_amb_k = T_amb_c + 273.15
    
    rho, mu = get_air_properties(T_amb_c)
      
    # Calculate Re at length L (device width)
    Re_L = rho * v * a / mu
    if Re_L >= 5e5:
        print(f"Warning: Reynolds number ({Re_L:.2e}) exceeds laminar flow limit (5e5).")
        print(f"The correlation may not be accurate for turbulent flow.")

    # Calculate average convection coefficient 
    h_a = 2 * 0.453 * params["Pr"]**(1/3) * (rho * v / mu)**0.5 * params["k_air"] * a**(-0.5)

    return h_a

def get_h_a_windless(T_amb_c, a):
    T_amb_k = T_amb_c + 273.15
    T_abs_k = 273.15 + 60              # assume 60C for the solar absorber 
    T_avg_k = (T_amb_k + T_abs_k) / 2  # Film temperature for properties

    rho, mu = get_air_properties(T_avg_k - 273.15)

    # Calculate kinematic viscosity
    nu = mu / rho  # m²/s

    # Gravitational acceleration
    g = 9.81  # m/s²

    # Coefficient of volume expansion for ideal gas: β = 1/T
    beta = 1 / T_avg_k  # 1/K
    
    # Characteristic length for horizontal plate
    l_c = a**2/(4*a)

    # Calculate Rayleigh number 
    Ra = (g * beta * abs(T_abs_k - T_amb_k) * l_c**3 * params["Pr"]) / (nu**2)

    # Check if Ra is in valid range
    if Ra < 1e4:
        print(f"Warning: Rayleigh number ({Ra:.2e}) is below the correlation range (10^4 to 10^7).")
        print(f"Natural convection may be negligible.")
    elif Ra > 1e7:
        print(f"Warning: Rayleigh number ({Ra:.2e}) exceeds the correlation range (10^4 to 10^7).")
        print(f"The correlation may not be accurate for turbulent natural convection.")

    # Calculate Nusselt number 
    h_a = 0.54 * Ra**0.25 * params["k_air"] / l_c

    return h_a

if params["v"] <= 0.1:  # Windless
    params["h_a"] = get_h_a_windless(params["T_amb_c"], params["a"])
else:  # Windy
    params["h_a"] = get_h_a_windy(params["T_amb_c"], params["v"], params["a"])

print(f'v={params["v"]}, h_a = {params["h_a"]}')
# Out:
# v=2.0, h_a = 33.73967385386665

# %%
# --- Load and process spectral data ---

try:
    # Load the data, skipping the first row (header) to avoid type errors
    data_folder = os.path.join("..", "data")
    file_path = os.path.join(data_folder, "PMMA_3mm_transmittance.csv")

    column_names = ['wavelength_um', 'transmittance_material', 'transmittance_atm']
    pmma_data = pd.read_csv(file_path, skiprows=1, names=column_names)

    for col in column_names:
        pmma_data[col] = pd.to_numeric(pmma_data[col])

    pmma_data['wavelength_m'] = pmma_data['wavelength_um'] * 1e-6

    pmma_data['delta_lambda'] = pmma_data['wavelength_m'].diff().bfill()

    print("Successfully loaded and processed PMMA and atmospheric spectral data.")
    
except Exception as e:
    print(f"Error loading or processing PMMA_3mm_transmittance.csv: {e}")
    pmma_data = None
# Out:
# Successfully loaded and processed PMMA and atmospheric spectral data.

# %%
# --- Helper Functions ---
def planck_law(wav, T):
    """Calculates spectral radiance using Planck's Law."""
    C1 = 3.7418e-16
    C2 = 1.4388e-2
    return (C1 / (wav**5)) / (np.exp(C2 / (wav * T)) - 1)

def calculate_q_rad(T_f_k, p, spectral_data):
    """
    Calculates q_rad by integrating Planck's law over the spectral data.
    """
    if spectral_data is None: return 0
    T_amb_k = p["T_amb_c"] + 273.15
    
    E_f = planck_law(spectral_data['wavelength_m'], T_f_k)
    E_amb = planck_law(spectral_data['wavelength_m'], T_amb_k)

    delta_lambda = spectral_data['delta_lambda']
    epsilon = p["epsilon"]

    if p["condition"] == 'indoor':
        integrand = p["epsilon"] * p["sigma"] * (T_f_k**4 - T_amb_k**4)
        q_rad = integrand.sum()
    else: # outdoor
        trans_atm = spectral_data['transmittance_atm']
        integrand = epsilon * (E_f - (1 - trans_atm) * E_amb) * delta_lambda
        q_rad = integrand.sum()       
    return q_rad

def calculate_saturation_concentration(T_k, activity=1.0):
    """
    Calculates water vapor saturation concentration (mol/m³) at a given temperature,
    using August-Roche-Magnus formula, adjusted for the solution's activity.
    """
    T_c = T_k - 273.15
    # P_sat_pure = 610.94 * np.exp((17.625 * T_c) / (T_c + 243.04)) # August-Roche-Magnus formula
    P_sat_pure = 133.32 * 10**8.07131 / 10**(1730.63/(T_c + 233.426)) # Antoine equation
    P_sat_solution = P_sat_pure * activity
    return P_sat_solution / (params["R_gas"] * T_k)

def solve_stage_backward(q_out, T_b_c, p, is_first_stage=False):
    """
    Solves a single stage backward to find the input heat and front wall temp.
    """
    T_b_k = T_b_c + 273.15

    def find_Tf_from_q_out(T_f_c, q_out_target, T_b_k, p):
        T_f_k = T_f_c + 273.15
        q_cond = p["k_air"] * (T_f_k - T_b_k) / p["b"]
        q_rad_int = 0.95 * p["sigma"]*(T_f_k**4 - T_b_k**4)
        # Use activity=0.98 for evaporating seawater at the front wall
        c_f = calculate_saturation_concentration(T_f_k, activity=0.98)
        # Use activity=1.0 for condensing pure water at the back wall
        c_b = calculate_saturation_concentration(T_b_k, activity=1.0)
        J_evap_molar = p["D_a"] * (c_f - c_b) / p["b"]
        q_evap = (J_evap_molar * p["M_water"]) * p["h_fg"]
        return (q_cond + q_evap + q_rad_int) - q_out_target

    initial_guess_T_f = T_b_c + 5.0
    T_f_c_solved = fsolve(find_Tf_from_q_out, initial_guess_T_f, args=(q_out, T_b_k, p))[0]
    T_f_k_solved = T_f_c_solved + 273.15

    T_amb_k = p["T_amb_c"] + 273.15
    R_side = (1 / p["h_a"]) + (p["t_ins"] / p["k"])
    T_avg_side_k = (T_f_k_solved + T_b_k) / 2
    q_side_flux = (T_avg_side_k - T_amb_k) / R_side
    q_side_per_front_area = q_side_flux * (4 * p["b"] / p["a"])

    q_in = q_out + q_side_per_front_area

    if is_first_stage:
        q_rad = calculate_q_rad(T_f_k_solved, p, pmma_data)
        q_conv = p["h_a"] * (T_f_k_solved - T_amb_k)
        q_in += q_rad + q_conv

    return q_in, T_f_c_solved

# %%
# --- Main Multi-Stage Simulation ---
def run_multistage_simulation(n_stages, params):

    q_out_n = params["q_sun"]* params["ref_abs"]
    tolerance = 0.1
    max_iterations = 100
    stage_data = []

    print(f"--- Running Multi-Stage Simulation for {n_stages} Stages ---\n")

    for iteration in range(max_iterations):
        current_stage_data = []
        q_out_current = q_out_n
        T_b_current_c = params["T_b_c"]

        for i in range(n_stages, 0, -1):
            is_first = (i == 1)
            q_in_current, T_f_current_c = solve_stage_backward(q_out_current, T_b_current_c, params, is_first_stage=is_first)
            current_stage_data.append({"stage": i, "T_f": T_f_current_c, "T_b": T_b_current_c})
            q_out_current = q_in_current
            T_b_current_c = T_f_current_c

        current_stage_data.reverse()
        q_in_1_calculated = q_out_current # This is now q_in of the first stage
        error = abs(q_in_1_calculated - params["q_sun"]* params["ref_abs"])

        print(f"Iteration {iteration + 1}: Calculated q_in,1 = {q_in_1_calculated:.2f} W/m^2, Error = {error:.2f} W/m^2")

        if error < tolerance:
            print("\nConvergence reached!")
            stage_data = current_stage_data
            break

        scaling_factor = params["q_sun"]* params["ref_abs"] / q_in_1_calculated
        q_out_n *= scaling_factor
    else:
        print("\nWarning: Maximum iterations reached without convergence.")
        stage_data = current_stage_data

    # --- Final Calculations and Output ---
    print("\n--- Per-Stage Detailed Results ---")
    total_evap_heat = 0
    for data in stage_data:
        T_f_c, T_b_c = data["T_f"], data["T_b"]
        T_f_k, T_b_k = T_f_c + 273.15, T_b_c + 273.15

        # Calculate vapor flux for this stage 
        c_f = calculate_saturation_concentration(T_f_k, activity=0.98)
        c_b = calculate_saturation_concentration(T_b_k, activity=1.0)
        J_evap_molar = params["D_a"] * (c_f - c_b) / params["b"]
        J_evap_mass = J_evap_molar * params["M_water"]
        J_evap_kg_hr = J_evap_mass * 3600
        
        # Calculate heat carried by evaporation
        q_evap = J_evap_mass * params["h_fg"]
        total_evap_heat += q_evap

        print(f"  Stage {data['stage']}: Evap Temp: {T_f_c:.2f}°C | Condensation Temp: {T_b_c:.2f}°C | Vapor Flux: {J_evap_kg_hr:.2f} kg/m²/hr")

    print("\n--- Overall Performance ---")
    eta_tot = total_evap_heat / params["q_sun"] * 0.9645
    total_vapor_flux_kg_hr = (total_evap_heat / params["h_fg"]) * 3600
    print(f"Total Vapor Mass Flux: {total_vapor_flux_kg_hr:.2f} kg/m²/hr")
    print(f"Total Efficiency (eta_tot): {eta_tot * 100:.2f}%")

    results = {
        "water productivity (kg/m2/hr)": round(total_vapor_flux_kg_hr, 2),
        "total efficiency (%)": round(eta_tot * 100, 2),
        "absorber temp (C)": round(stage_data[0]['T_f'], 2) if stage_data else None,
    }
    return results

# %% [markdown]
# # Simulation Cases in Figure 3

# %%
simulation_cases_Fig3 = [
    {
        "name": "Indoor, windless, 25C", #Figure 3b
        "condition": 'indoor',
        "v": 0,
    },    
    {
        "name": "Indoor, 2 m/s wind, 25C", #Figure 3b
        "condition": 'indoor',
        "v": 2.0,
    },
    {
        "name": "Indoor, 4 m/s wind, 25C", #Figure 3b
        "condition": 'indoor',
        "v": 4.0,
    },
    {
        "name": "Indoor, 6 m/s wind, 25C", #Figure 3b
        "condition": 'indoor',
        "v": 6.0,
    },   
    {
        "name": "Outdoor, windless, 25C", #Figure 3c
        "condition": "outdoor",
        "v": 0,
    },       
    {
        "name": "Outdoor, 2 m/s wind, 25C", #Figure 3c
        "condition": "outdoor",
        "v": 2.0,
    },      
    {
        "name": "Outdoor, windless, 20C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 25,
        "T_amb_c": 20,
        "v": 0, 
    },
    {
        "name": "Outdoor, windless, 30C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 35,
        "T_amb_c": 30,
        "v": 0, 
    },
    {
        "name": "Outdoor, windless, 35C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 40,
        "T_amb_c": 35,
        "v": 0,
    },
    {
        "name": "Outdoor, windless, 40C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 45,
        "T_amb_c": 40,
        "v": 0, 
    },    
    {
        "name": "Outdoor, 0.7 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 700, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    },
    {
        "name": "Outdoor, 0.5 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 500, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    }, 
    {
        "name": "Outdoor, 0.3 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 300, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    },    
]

# %%
# --- Run the Simulation ---
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
if __name__ == "__main__":
    number_of_stages =  6

    all_results_data = []

    for case in simulation_cases_Fig3:
        print(f"\n========================================================")
        print(f"Running: {case['name']}")
        print(f"========================================================")

        current_params = params.copy()
        current_params.update(case)

        if current_params["v"] <= 0.1:  # Windless
            current_params["h_a"] = get_h_a_windless(current_params["T_amb_c"], current_params["a"])
        else:  # Windy
            current_params["h_a"] = get_h_a_windy(current_params["T_amb_c"], current_params["v"], current_params["a"])

         # Run Simulation
        output_results = run_multistage_simulation(number_of_stages, current_params)

        result_row = {"name": case["name"]}
        result_row.update(output_results)
        
        all_results_data.append(result_row)
        

    results_df = pd.DataFrame(all_results_data)
    
    output_folder = os.path.join("results")

    output_filename = os.path.join(output_folder, f"No_cover_simulation_Fig3_summary_{timestamp}.csv")
    results_df.to_csv(output_filename, index=False)

    print(f"\n\n All simulations complete. Results saved to '{output_filename}'")

# %% [markdown]
# # Wind speed vs module dimension (Figure _)

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
params["condition"] = 'outdoor'
device_widths = [0.05, 0.1, 0.2, 0.5, 1.0, 2.0]  # meters
windspeeds = [0, 2, 4, 6, 8, 10]  # m/s

simulation_cases = [
    {"name": f"a={a:.2f}m_v={v}m/s" if v > 0 else f"a={a:.2f}m_windless",
     "a": a, "v": v}
    for a in device_widths for v in windspeeds]

print(f"Running {len(simulation_cases)} cases...")

if __name__ == "__main__":
    number_of_stages =  6
    all_results_data = []

    for i, case in enumerate(simulation_cases, 1):
        print(f"\n[{i}/{len(simulation_cases)}] {case['name']}")

        current_params = params.copy()
        current_params.update(case)
        
        if current_params["v"] <= 0.1:  
            current_params["h_a"] = get_h_a_windless(current_params["T_amb_c"], current_params["a"])
        else:  
            current_params["h_a"] = get_h_a_windy(current_params["T_amb_c"], current_params["v"], current_params["a"])

        output_results = run_multistage_simulation(number_of_stages, current_params)

        result_row = {"case_number": i, "name": case["name"]}
        result_row.update(output_results)
        all_results_data.append(result_row)
        

    results_df = pd.DataFrame(all_results_data)
    output_folder = os.path.join("results")
    output_filename = os.path.join(output_folder, f"No_cover_FigS15a_simulation_summary_{timestamp}.csv")
    results_df.to_csv(output_filename, index=False)

    print(f"\n\n All simulations complete. Results saved to '{output_filename}'")

# %% [markdown]
# # T<sub>amb</sub> vs Stage number (Figure S15)

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
params["v"] = 0.1
params["condition"] = 'outdoor'
stage_number = [2, 4, 6, 8, 10, 12]
ambient_temp = [15, 20, 25, 30, 35, 40, 45]  # °C

simulation_cases = [
    {"name": f"n={n}_T={T}C", "n_stages": n, "T_amb_c": T}
    for n in stage_number
    for T in ambient_temp]

print(f"Running {len(simulation_cases)} cases...")

if __name__ == "__main__":
    all_results_data = []
    
    for i, case in enumerate(simulation_cases, 1):
        print(f"\n[{i}/{len(simulation_cases)}] {case['name']}")
        
        current_params = params.copy()
        current_params.update(case)
        n_stages = case["n_stages"]
        
        if current_params["v"] <= 0.1:
            current_params["h_a"] = get_h_a_windless(current_params["T_amb_c"], current_params["a"])
        else:
            current_params["h_a"] = get_h_a_windy(current_params["T_amb_c"], current_params["v"], current_params["a"])
            
        output_results = run_multistage_simulation(n_stages, current_params)

        result_row = {"case_number": i, "name": case["name"], 
                     "n_stages": n_stages, "T_amb_c": case["T_amb_c"]}
        result_row.update(output_results)
        all_results_data.append(result_row)

    results_df = pd.DataFrame(all_results_data)
    output_folder = os.path.join("results")
    output_filename = os.path.join(output_folder, f"No_cover_FigS15b_simulation_summary_{timestamp}_outdoor.csv")
    results_df.to_csv(output_filename, index=False)

    print(f"\n\n All simulations complete. Results saved to '{output_filename}'")
# Out:
# Running 42 cases...
#
# [1/42] n=2_T=15C
# Warning: Rayleigh number (7.08e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1832.56 W/m^2, Error = 868.06 W/m^2
# Iteration 2: Calculated q_in,1 = 1205.98 W/m^2, Error = 241.48 W/m^2
# Iteration 3: Calculated q_in,1 = 1058.97 W/m^2, Error = 94.47 W/m^2
# Iteration 4: Calculated q_in,1 = 1005.69 W/m^2, Error = 41.19 W/m^2
# Iteration 5: Calculated q_in,1 = 983.25 W/m^2, Error = 18.75 W/m^2
# Iteration 6: Calculated q_in,1 = 973.20 W/m^2, Error = 8.70 W/m^2
# Iteration 7: Calculated q_in,1 = 968.57 W/m^2, Error = 4.07 W/m^2
# Iteration 8: Calculated q_in,1 = 966.42 W/m^2, Error = 1.92 W/m^2
# Iteration 9: Calculated q_in,1 = 965.40 W/m^2, Error = 0.90 W/m^2
# Iteration 10: Calculated q_in,1 = 964.93 W/m^2, Error = 0.43 W/m^2
# Iteration 11: Calculated q_in,1 = 964.70 W/m^2, Error = 0.20 W/m^2
# Iteration 12: Calculated q_in,1 = 964.59 W/m^2, Error = 0.09 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 42.69°C | Condensation Temp: 36.86°C | Vapor Flux: 0.42 kg/m²/hr
#   Stage 2: Evap Temp: 36.86°C | Condensation Temp: 30.00°C | Vapor Flux: 0.38 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 0.80 kg/m²/hr
# Total Efficiency (eta_tot): 50.50%
#
# [2/42] n=2_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1748.71 W/m^2, Error = 784.21 W/m^2
# Iteration 2: Calculated q_in,1 = 1160.22 W/m^2, Error = 195.72 W/m^2
# Iteration 3: Calculated q_in,1 = 1032.19 W/m^2, Error = 67.69 W/m^2
# Iteration 4: Calculated q_in,1 = 990.24 W/m^2, Error = 25.74 W/m^2
# Iteration 5: Calculated q_in,1 = 974.63 W/m^2, Error = 10.13 W/m^2
# Iteration 6: Calculated q_in,1 = 968.54 W/m^2, Error = 4.04 W/m^2
# Iteration 7: Calculated q_in,1 = 966.12 W/m^2, Error = 1.62 W/m^2
# Iteration 8: Calculated q_in,1 = 965.15 W/m^2, Error = 0.65 W/m^2
# Iteration 9: Calculated q_in,1 = 964.76 W/m^2, Error = 0.26 W/m^2
# Iteration 10: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
# Iteration 11: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 44.13°C | Condensation Temp: 37.77°C | Vapor Flux: 0.48 kg/m²/hr
#   Stage 2: Evap Temp: 37.77°C | Condensation Temp: 30.00°C | Vapor Flux: 0.44 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 0.93 kg/m²/hr
# Total Efficiency (eta_tot): 58.48%
#
# [3/42] n=2_T=25C
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1667.65 W/m^2, Error = 703.15 W/m^2
# Iteration 2: Calculated q_in,1 = 1118.95 W/m^2, Error = 154.45 W/m^2
# Iteration 3: Calculated q_in,1 = 1010.62 W/m^2, Error = 46.12 W/m^2
# Iteration 4: Calculated q_in,1 = 979.42 W/m^2, Error = 14.92 W/m^2
# Iteration 5: Calculated q_in,1 = 969.45 W/m^2, Error = 4.95 W/m^2
# Iteration 6: Calculated q_in,1 = 966.15 W/m^2, Error = 1.65 W/m^2
# Iteration 7: Calculated q_in,1 = 965.05 W/m^2, Error = 0.55 W/m^2
# Iteration 8: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 9: Calculated q_in,1 = 964.56 W/m^2, Error = 0.06 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 45.48°C | Condensation Temp: 38.64°C | Vapor Flux: 0.55 kg/m²/hr
#   Stage 2: Evap Temp: 38.64°C | Condensation Temp: 30.00°C | Vapor Flux: 0.50 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.05 kg/m²/hr
# Total Efficiency (eta_tot): 66.46%
#
# [4/42] n=2_T=30C
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1589.51 W/m^2, Error = 625.01 W/m^2
# Iteration 2: Calculated q_in,1 = 1082.34 W/m^2, Error = 117.84 W/m^2
# Iteration 3: Calculated q_in,1 = 993.97 W/m^2, Error = 29.47 W/m^2
# Iteration 4: Calculated q_in,1 = 972.36 W/m^2, Error = 7.86 W/m^2
# Iteration 5: Calculated q_in,1 = 966.63 W/m^2, Error = 2.13 W/m^2
# Iteration 6: Calculated q_in,1 = 965.08 W/m^2, Error = 0.58 W/m^2
# Iteration 7: Calculated q_in,1 = 964.66 W/m^2, Error = 0.16 W/m^2
# Iteration 8: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 46.75°C | Condensation Temp: 39.47°C | Vapor Flux: 0.61 kg/m²/hr
#   Stage 2: Evap Temp: 39.47°C | Condensation Temp: 30.00°C | Vapor Flux: 0.57 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.18 kg/m²/hr
# Total Efficiency (eta_tot): 74.36%
#
# [5/42] n=2_T=35C
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1514.51 W/m^2, Error = 550.01 W/m^2
# Iteration 2: Calculated q_in,1 = 1050.56 W/m^2, Error = 86.06 W/m^2
# Iteration 3: Calculated q_in,1 = 981.81 W/m^2, Error = 17.31 W/m^2
# Iteration 4: Calculated q_in,1 = 968.15 W/m^2, Error = 3.65 W/m^2
# Iteration 5: Calculated q_in,1 = 965.28 W/m^2, Error = 0.78 W/m^2
# Iteration 6: Calculated q_in,1 = 964.67 W/m^2, Error = 0.17 W/m^2
# Iteration 7: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 47.95°C | Condensation Temp: 40.26°C | Vapor Flux: 0.67 kg/m²/hr
#   Stage 2: Evap Temp: 40.26°C | Condensation Temp: 30.00°C | Vapor Flux: 0.63 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.30 kg/m²/hr
# Total Efficiency (eta_tot): 82.16%
#
# [6/42] n=2_T=40C
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1443.01 W/m^2, Error = 478.51 W/m^2
# Iteration 2: Calculated q_in,1 = 1023.79 W/m^2, Error = 59.29 W/m^2
# Iteration 3: Calculated q_in,1 = 973.56 W/m^2, Error = 9.06 W/m^2
# Iteration 4: Calculated q_in,1 = 965.93 W/m^2, Error = 1.43 W/m^2
# Iteration 5: Calculated q_in,1 = 964.73 W/m^2, Error = 0.23 W/m^2
# Iteration 6: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 49.06°C | Condensation Temp: 41.01°C | Vapor Flux: 0.74 kg/m²/hr
#   Stage 2: Evap Temp: 41.01°C | Condensation Temp: 30.00°C | Vapor Flux: 0.69 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.42 kg/m²/hr
# Total Efficiency (eta_tot): 89.77%
#
# [7/42] n=2_T=45C
# Warning: Rayleigh number (1.91e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 2 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1375.57 W/m^2, Error = 411.07 W/m^2
# Iteration 2: Calculated q_in,1 = 1002.24 W/m^2, Error = 37.74 W/m^2
# Iteration 3: Calculated q_in,1 = 968.54 W/m^2, Error = 4.04 W/m^2
# Iteration 4: Calculated q_in,1 = 964.94 W/m^2, Error = 0.44 W/m^2
# Iteration 5: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 50.08°C | Condensation Temp: 41.71°C | Vapor Flux: 0.79 kg/m²/hr
#   Stage 2: Evap Temp: 41.71°C | Condensation Temp: 30.00°C | Vapor Flux: 0.74 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.54 kg/m²/hr
# Total Efficiency (eta_tot): 97.09%
#
# [8/42] n=4_T=15C
# Warning: Rayleigh number (7.08e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2177.24 W/m^2, Error = 1212.74 W/m^2
# Iteration 2: Calculated q_in,1 = 1331.21 W/m^2, Error = 366.71 W/m^2
# Iteration 3: Calculated q_in,1 = 1122.32 W/m^2, Error = 157.82 W/m^2
# Iteration 4: Calculated q_in,1 = 1041.49 W/m^2, Error = 76.99 W/m^2
# Iteration 5: Calculated q_in,1 = 1004.22 W/m^2, Error = 39.72 W/m^2
# Iteration 6: Calculated q_in,1 = 985.57 W/m^2, Error = 21.07 W/m^2
# Iteration 7: Calculated q_in,1 = 975.84 W/m^2, Error = 11.34 W/m^2
# Iteration 8: Calculated q_in,1 = 970.65 W/m^2, Error = 6.15 W/m^2
# Iteration 9: Calculated q_in,1 = 967.84 W/m^2, Error = 3.34 W/m^2
# Iteration 10: Calculated q_in,1 = 966.32 W/m^2, Error = 1.82 W/m^2
# Iteration 11: Calculated q_in,1 = 965.50 W/m^2, Error = 1.00 W/m^2
# Iteration 12: Calculated q_in,1 = 965.04 W/m^2, Error = 0.54 W/m^2
# Iteration 13: Calculated q_in,1 = 964.80 W/m^2, Error = 0.30 W/m^2
# Iteration 14: Calculated q_in,1 = 964.66 W/m^2, Error = 0.16 W/m^2
# Iteration 15: Calculated q_in,1 = 964.59 W/m^2, Error = 0.09 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 47.20°C | Condensation Temp: 43.28°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 2: Evap Temp: 43.28°C | Condensation Temp: 39.17°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 3: Evap Temp: 39.17°C | Condensation Temp: 34.78°C | Vapor Flux: 0.27 kg/m²/hr
#   Stage 4: Evap Temp: 34.78°C | Condensation Temp: 30.00°C | Vapor Flux: 0.25 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.16 kg/m²/hr
# Total Efficiency (eta_tot): 73.45%
#
# [9/42] n=4_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2076.64 W/m^2, Error = 1112.14 W/m^2
# Iteration 2: Calculated q_in,1 = 1270.90 W/m^2, Error = 306.40 W/m^2
# Iteration 3: Calculated q_in,1 = 1082.95 W/m^2, Error = 118.45 W/m^2
# Iteration 4: Calculated q_in,1 = 1015.73 W/m^2, Error = 51.23 W/m^2
# Iteration 5: Calculated q_in,1 = 987.70 W/m^2, Error = 23.20 W/m^2
# Iteration 6: Calculated q_in,1 = 975.22 W/m^2, Error = 10.72 W/m^2
# Iteration 7: Calculated q_in,1 = 969.50 W/m^2, Error = 5.00 W/m^2
# Iteration 8: Calculated q_in,1 = 966.84 W/m^2, Error = 2.34 W/m^2
# Iteration 9: Calculated q_in,1 = 965.60 W/m^2, Error = 1.10 W/m^2
# Iteration 10: Calculated q_in,1 = 965.02 W/m^2, Error = 0.52 W/m^2
# Iteration 11: Calculated q_in,1 = 964.74 W/m^2, Error = 0.24 W/m^2
# Iteration 12: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 13: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 49.32°C | Condensation Temp: 45.15°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 2: Evap Temp: 45.15°C | Condensation Temp: 40.65°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 3: Evap Temp: 40.65°C | Condensation Temp: 35.68°C | Vapor Flux: 0.33 kg/m²/hr
#   Stage 4: Evap Temp: 35.68°C | Condensation Temp: 30.00°C | Vapor Flux: 0.30 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.39 kg/m²/hr
# Total Efficiency (eta_tot): 87.49%
#
# [10/42] n=4_T=25C
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1978.70 W/m^2, Error = 1014.20 W/m^2
# Iteration 2: Calculated q_in,1 = 1215.36 W/m^2, Error = 250.86 W/m^2
# Iteration 3: Calculated q_in,1 = 1049.91 W/m^2, Error = 85.41 W/m^2
# Iteration 4: Calculated q_in,1 = 996.54 W/m^2, Error = 32.04 W/m^2
# Iteration 5: Calculated q_in,1 = 976.95 W/m^2, Error = 12.45 W/m^2
# Iteration 6: Calculated q_in,1 = 969.40 W/m^2, Error = 4.90 W/m^2
# Iteration 7: Calculated q_in,1 = 966.44 W/m^2, Error = 1.94 W/m^2
# Iteration 8: Calculated q_in,1 = 965.27 W/m^2, Error = 0.77 W/m^2
# Iteration 9: Calculated q_in,1 = 964.81 W/m^2, Error = 0.31 W/m^2
# Iteration 10: Calculated q_in,1 = 964.62 W/m^2, Error = 0.12 W/m^2
# Iteration 11: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 51.32°C | Condensation Temp: 46.93°C | Vapor Flux: 0.45 kg/m²/hr
#   Stage 2: Evap Temp: 46.93°C | Condensation Temp: 42.08°C | Vapor Flux: 0.42 kg/m²/hr
#   Stage 3: Evap Temp: 42.08°C | Condensation Temp: 36.56°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 4: Evap Temp: 36.56°C | Condensation Temp: 30.00°C | Vapor Flux: 0.36 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.61 kg/m²/hr
# Total Efficiency (eta_tot): 101.87%
#
# [11/42] n=4_T=30C
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1883.48 W/m^2, Error = 918.98 W/m^2
# Iteration 2: Calculated q_in,1 = 1164.81 W/m^2, Error = 200.31 W/m^2
# Iteration 3: Calculated q_in,1 = 1023.08 W/m^2, Error = 58.58 W/m^2
# Iteration 4: Calculated q_in,1 = 983.05 W/m^2, Error = 18.55 W/m^2
# Iteration 5: Calculated q_in,1 = 970.52 W/m^2, Error = 6.02 W/m^2
# Iteration 6: Calculated q_in,1 = 966.47 W/m^2, Error = 1.97 W/m^2
# Iteration 7: Calculated q_in,1 = 965.15 W/m^2, Error = 0.65 W/m^2
# Iteration 8: Calculated q_in,1 = 964.71 W/m^2, Error = 0.21 W/m^2
# Iteration 9: Calculated q_in,1 = 964.57 W/m^2, Error = 0.07 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 53.20°C | Condensation Temp: 48.61°C | Vapor Flux: 0.50 kg/m²/hr
#   Stage 2: Evap Temp: 48.61°C | Condensation Temp: 43.45°C | Vapor Flux: 0.48 kg/m²/hr
#   Stage 3: Evap Temp: 43.45°C | Condensation Temp: 37.42°C | Vapor Flux: 0.45 kg/m²/hr
#   Stage 4: Evap Temp: 37.42°C | Condensation Temp: 30.00°C | Vapor Flux: 0.42 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.85 kg/m²/hr
# Total Efficiency (eta_tot): 116.53%
#
# [12/42] n=4_T=35C
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1791.07 W/m^2, Error = 826.57 W/m^2
# Iteration 2: Calculated q_in,1 = 1119.48 W/m^2, Error = 154.98 W/m^2
# Iteration 3: Calculated q_in,1 = 1002.18 W/m^2, Error = 37.68 W/m^2
# Iteration 4: Calculated q_in,1 = 974.23 W/m^2, Error = 9.73 W/m^2
# Iteration 5: Calculated q_in,1 = 967.05 W/m^2, Error = 2.55 W/m^2
# Iteration 6: Calculated q_in,1 = 965.17 W/m^2, Error = 0.67 W/m^2
# Iteration 7: Calculated q_in,1 = 964.68 W/m^2, Error = 0.18 W/m^2
# Iteration 8: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 54.98°C | Condensation Temp: 50.21°C | Vapor Flux: 0.56 kg/m²/hr
#   Stage 2: Evap Temp: 50.21°C | Condensation Temp: 44.76°C | Vapor Flux: 0.53 kg/m²/hr
#   Stage 3: Evap Temp: 44.76°C | Condensation Temp: 38.25°C | Vapor Flux: 0.51 kg/m²/hr
#   Stage 4: Evap Temp: 38.25°C | Condensation Temp: 30.00°C | Vapor Flux: 0.48 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.08 kg/m²/hr
# Total Efficiency (eta_tot): 131.34%
#
# [13/42] n=4_T=40C
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1701.60 W/m^2, Error = 737.10 W/m^2
# Iteration 2: Calculated q_in,1 = 1079.68 W/m^2, Error = 115.18 W/m^2
# Iteration 3: Calculated q_in,1 = 986.78 W/m^2, Error = 22.28 W/m^2
# Iteration 4: Calculated q_in,1 = 968.99 W/m^2, Error = 4.49 W/m^2
# Iteration 5: Calculated q_in,1 = 965.41 W/m^2, Error = 0.91 W/m^2
# Iteration 6: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 7: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 56.66°C | Condensation Temp: 51.73°C | Vapor Flux: 0.62 kg/m²/hr
#   Stage 2: Evap Temp: 51.73°C | Condensation Temp: 46.01°C | Vapor Flux: 0.59 kg/m²/hr
#   Stage 3: Evap Temp: 46.01°C | Condensation Temp: 39.06°C | Vapor Flux: 0.57 kg/m²/hr
#   Stage 4: Evap Temp: 39.06°C | Condensation Temp: 30.00°C | Vapor Flux: 0.54 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.32 kg/m²/hr
# Total Efficiency (eta_tot): 146.23%
#
# [14/42] n=4_T=45C
# Warning: Rayleigh number (1.91e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 4 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1615.27 W/m^2, Error = 650.77 W/m^2
# Iteration 2: Calculated q_in,1 = 1045.79 W/m^2, Error = 81.29 W/m^2
# Iteration 3: Calculated q_in,1 = 976.30 W/m^2, Error = 11.80 W/m^2
# Iteration 4: Calculated q_in,1 = 966.25 W/m^2, Error = 1.75 W/m^2
# Iteration 5: Calculated q_in,1 = 964.76 W/m^2, Error = 0.26 W/m^2
# Iteration 6: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 58.23°C | Condensation Temp: 53.15°C | Vapor Flux: 0.68 kg/m²/hr
#   Stage 2: Evap Temp: 53.15°C | Condensation Temp: 47.19°C | Vapor Flux: 0.65 kg/m²/hr
#   Stage 3: Evap Temp: 47.19°C | Condensation Temp: 39.83°C | Vapor Flux: 0.63 kg/m²/hr
#   Stage 4: Evap Temp: 39.83°C | Condensation Temp: 30.00°C | Vapor Flux: 0.59 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.55 kg/m²/hr
# Total Efficiency (eta_tot): 161.05%
#
# [15/42] n=6_T=15C
# Warning: Rayleigh number (7.08e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2487.47 W/m^2, Error = 1522.97 W/m^2
# Iteration 2: Calculated q_in,1 = 1459.85 W/m^2, Error = 495.35 W/m^2
# Iteration 3: Calculated q_in,1 = 1194.95 W/m^2, Error = 230.45 W/m^2
# Iteration 4: Calculated q_in,1 = 1087.53 W/m^2, Error = 123.03 W/m^2
# Iteration 5: Calculated q_in,1 = 1034.72 W/m^2, Error = 70.22 W/m^2
# Iteration 6: Calculated q_in,1 = 1006.05 W/m^2, Error = 41.55 W/m^2
# Iteration 7: Calculated q_in,1 = 989.59 W/m^2, Error = 25.09 W/m^2
# Iteration 8: Calculated q_in,1 = 979.84 W/m^2, Error = 15.34 W/m^2
# Iteration 9: Calculated q_in,1 = 973.95 W/m^2, Error = 9.45 W/m^2
# Iteration 10: Calculated q_in,1 = 970.34 W/m^2, Error = 5.84 W/m^2
# Iteration 11: Calculated q_in,1 = 968.12 W/m^2, Error = 3.62 W/m^2
# Iteration 12: Calculated q_in,1 = 966.75 W/m^2, Error = 2.25 W/m^2
# Iteration 13: Calculated q_in,1 = 965.90 W/m^2, Error = 1.40 W/m^2
# Iteration 14: Calculated q_in,1 = 965.37 W/m^2, Error = 0.87 W/m^2
# Iteration 15: Calculated q_in,1 = 965.04 W/m^2, Error = 0.54 W/m^2
# Iteration 16: Calculated q_in,1 = 964.84 W/m^2, Error = 0.34 W/m^2
# Iteration 17: Calculated q_in,1 = 964.71 W/m^2, Error = 0.21 W/m^2
# Iteration 18: Calculated q_in,1 = 964.63 W/m^2, Error = 0.13 W/m^2
# Iteration 19: Calculated q_in,1 = 964.58 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 49.34°C | Condensation Temp: 46.14°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 2: Evap Temp: 46.14°C | Condensation Temp: 42.95°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 3: Evap Temp: 42.95°C | Condensation Temp: 39.75°C | Vapor Flux: 0.23 kg/m²/hr
#   Stage 4: Evap Temp: 39.75°C | Condensation Temp: 36.54°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 5: Evap Temp: 36.54°C | Condensation Temp: 33.30°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 6: Evap Temp: 33.30°C | Condensation Temp: 30.00°C | Vapor Flux: 0.16 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.33 kg/m²/hr
# Total Efficiency (eta_tot): 83.85%
#
# [16/42] n=6_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2370.70 W/m^2, Error = 1406.20 W/m^2
# Iteration 2: Calculated q_in,1 = 1384.25 W/m^2, Error = 419.75 W/m^2
# Iteration 3: Calculated q_in,1 = 1141.11 W/m^2, Error = 176.61 W/m^2
# Iteration 4: Calculated q_in,1 = 1048.67 W/m^2, Error = 84.17 W/m^2
# Iteration 5: Calculated q_in,1 = 1006.91 W/m^2, Error = 42.41 W/m^2
# Iteration 6: Calculated q_in,1 = 986.46 W/m^2, Error = 21.96 W/m^2
# Iteration 7: Calculated q_in,1 = 976.03 W/m^2, Error = 11.53 W/m^2
# Iteration 8: Calculated q_in,1 = 970.60 W/m^2, Error = 6.10 W/m^2
# Iteration 9: Calculated q_in,1 = 967.74 W/m^2, Error = 3.24 W/m^2
# Iteration 10: Calculated q_in,1 = 966.22 W/m^2, Error = 1.72 W/m^2
# Iteration 11: Calculated q_in,1 = 965.42 W/m^2, Error = 0.92 W/m^2
# Iteration 12: Calculated q_in,1 = 964.99 W/m^2, Error = 0.49 W/m^2
# Iteration 13: Calculated q_in,1 = 964.76 W/m^2, Error = 0.26 W/m^2
# Iteration 14: Calculated q_in,1 = 964.64 W/m^2, Error = 0.14 W/m^2
# Iteration 15: Calculated q_in,1 = 964.57 W/m^2, Error = 0.07 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 51.94°C | Condensation Temp: 48.62°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 2: Evap Temp: 48.62°C | Condensation Temp: 45.22°C | Vapor Flux: 0.31 kg/m²/hr
#   Stage 3: Evap Temp: 45.22°C | Condensation Temp: 41.72°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 4: Evap Temp: 41.72°C | Condensation Temp: 38.06°C | Vapor Flux: 0.25 kg/m²/hr
#   Stage 5: Evap Temp: 38.06°C | Condensation Temp: 34.19°C | Vapor Flux: 0.23 kg/m²/hr
#   Stage 6: Evap Temp: 34.19°C | Condensation Temp: 30.00°C | Vapor Flux: 0.21 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.62 kg/m²/hr
# Total Efficiency (eta_tot): 102.36%
#
# [17/42] n=6_T=25C
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2256.53 W/m^2, Error = 1292.03 W/m^2
# Iteration 2: Calculated q_in,1 = 1313.91 W/m^2, Error = 349.41 W/m^2
# Iteration 3: Calculated q_in,1 = 1095.03 W/m^2, Error = 130.53 W/m^2
# Iteration 4: Calculated q_in,1 = 1018.83 W/m^2, Error = 54.33 W/m^2
# Iteration 5: Calculated q_in,1 = 988.12 W/m^2, Error = 23.62 W/m^2
# Iteration 6: Calculated q_in,1 = 974.96 W/m^2, Error = 10.46 W/m^2
# Iteration 7: Calculated q_in,1 = 969.17 W/m^2, Error = 4.67 W/m^2
# Iteration 8: Calculated q_in,1 = 966.59 W/m^2, Error = 2.09 W/m^2
# Iteration 9: Calculated q_in,1 = 965.44 W/m^2, Error = 0.94 W/m^2
# Iteration 10: Calculated q_in,1 = 964.92 W/m^2, Error = 0.42 W/m^2
# Iteration 11: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 12: Calculated q_in,1 = 964.59 W/m^2, Error = 0.09 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 54.40°C | Condensation Temp: 50.97°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 2: Evap Temp: 50.97°C | Condensation Temp: 47.39°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 3: Evap Temp: 47.39°C | Condensation Temp: 43.61°C | Vapor Flux: 0.33 kg/m²/hr
#   Stage 4: Evap Temp: 43.61°C | Condensation Temp: 39.54°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 5: Evap Temp: 39.54°C | Condensation Temp: 35.07°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 6: Evap Temp: 35.07°C | Condensation Temp: 30.00°C | Vapor Flux: 0.26 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.93 kg/m²/hr
# Total Efficiency (eta_tot): 121.73%
#
# [18/42] n=6_T=30C
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2144.94 W/m^2, Error = 1180.44 W/m^2
# Iteration 2: Calculated q_in,1 = 1249.10 W/m^2, Error = 284.60 W/m^2
# Iteration 3: Calculated q_in,1 = 1056.69 W/m^2, Error = 92.19 W/m^2
# Iteration 4: Calculated q_in,1 = 997.14 W/m^2, Error = 32.64 W/m^2
# Iteration 5: Calculated q_in,1 = 976.42 W/m^2, Error = 11.92 W/m^2
# Iteration 6: Calculated q_in,1 = 968.90 W/m^2, Error = 4.40 W/m^2
# Iteration 7: Calculated q_in,1 = 966.13 W/m^2, Error = 1.63 W/m^2
# Iteration 8: Calculated q_in,1 = 965.11 W/m^2, Error = 0.61 W/m^2
# Iteration 9: Calculated q_in,1 = 964.73 W/m^2, Error = 0.23 W/m^2
# Iteration 10: Calculated q_in,1 = 964.58 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 56.74°C | Condensation Temp: 53.21°C | Vapor Flux: 0.44 kg/m²/hr
#   Stage 2: Evap Temp: 53.21°C | Condensation Temp: 49.46°C | Vapor Flux: 0.41 kg/m²/hr
#   Stage 3: Evap Temp: 49.46°C | Condensation Temp: 45.43°C | Vapor Flux: 0.38 kg/m²/hr
#   Stage 4: Evap Temp: 45.43°C | Condensation Temp: 40.98°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 5: Evap Temp: 40.98°C | Condensation Temp: 35.95°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 6: Evap Temp: 35.95°C | Condensation Temp: 30.00°C | Vapor Flux: 0.32 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.25 kg/m²/hr
# Total Efficiency (eta_tot): 141.84%
#
# [19/42] n=6_T=35C
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2035.95 W/m^2, Error = 1071.45 W/m^2
# Iteration 2: Calculated q_in,1 = 1190.10 W/m^2, Error = 225.60 W/m^2
# Iteration 3: Calculated q_in,1 = 1025.96 W/m^2, Error = 61.46 W/m^2
# Iteration 4: Calculated q_in,1 = 982.39 W/m^2, Error = 17.89 W/m^2
# Iteration 5: Calculated q_in,1 = 969.81 W/m^2, Error = 5.31 W/m^2
# Iteration 6: Calculated q_in,1 = 966.09 W/m^2, Error = 1.59 W/m^2
# Iteration 7: Calculated q_in,1 = 964.97 W/m^2, Error = 0.47 W/m^2
# Iteration 8: Calculated q_in,1 = 964.64 W/m^2, Error = 0.14 W/m^2
# Iteration 9: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 58.95°C | Condensation Temp: 55.33°C | Vapor Flux: 0.49 kg/m²/hr
#   Stage 2: Evap Temp: 55.33°C | Condensation Temp: 51.44°C | Vapor Flux: 0.46 kg/m²/hr
#   Stage 3: Evap Temp: 51.44°C | Condensation Temp: 47.17°C | Vapor Flux: 0.44 kg/m²/hr
#   Stage 4: Evap Temp: 47.17°C | Condensation Temp: 42.38°C | Vapor Flux: 0.42 kg/m²/hr
#   Stage 5: Evap Temp: 42.38°C | Condensation Temp: 36.81°C | Vapor Flux: 0.40 kg/m²/hr
#   Stage 6: Evap Temp: 36.81°C | Condensation Temp: 30.00°C | Vapor Flux: 0.38 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.57 kg/m²/hr
# Total Efficiency (eta_tot): 162.58%
#
# [20/42] n=6_T=40C
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1929.51 W/m^2, Error = 965.01 W/m^2
# Iteration 2: Calculated q_in,1 = 1137.31 W/m^2, Error = 172.81 W/m^2
# Iteration 3: Calculated q_in,1 = 1002.51 W/m^2, Error = 38.01 W/m^2
# Iteration 4: Calculated q_in,1 = 973.22 W/m^2, Error = 8.72 W/m^2
# Iteration 5: Calculated q_in,1 = 966.52 W/m^2, Error = 2.02 W/m^2
# Iteration 6: Calculated q_in,1 = 964.97 W/m^2, Error = 0.47 W/m^2
# Iteration 7: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 8: Calculated q_in,1 = 964.53 W/m^2, Error = 0.03 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 61.05°C | Condensation Temp: 57.34°C | Vapor Flux: 0.54 kg/m²/hr
#   Stage 2: Evap Temp: 57.34°C | Condensation Temp: 53.32°C | Vapor Flux: 0.51 kg/m²/hr
#   Stage 3: Evap Temp: 53.32°C | Condensation Temp: 48.84°C | Vapor Flux: 0.49 kg/m²/hr
#   Stage 4: Evap Temp: 48.84°C | Condensation Temp: 43.73°C | Vapor Flux: 0.47 kg/m²/hr
#   Stage 5: Evap Temp: 43.73°C | Condensation Temp: 37.65°C | Vapor Flux: 0.46 kg/m²/hr
#   Stage 6: Evap Temp: 37.65°C | Condensation Temp: 30.00°C | Vapor Flux: 0.43 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.91 kg/m²/hr
# Total Efficiency (eta_tot): 183.85%
#
# [21/42] n=6_T=45C
# Warning: Rayleigh number (1.91e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1825.52 W/m^2, Error = 861.02 W/m^2
# Iteration 2: Calculated q_in,1 = 1091.24 W/m^2, Error = 126.74 W/m^2
# Iteration 3: Calculated q_in,1 = 985.81 W/m^2, Error = 21.31 W/m^2
# Iteration 4: Calculated q_in,1 = 968.14 W/m^2, Error = 3.64 W/m^2
# Iteration 5: Calculated q_in,1 = 965.12 W/m^2, Error = 0.62 W/m^2
# Iteration 6: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 7: Calculated q_in,1 = 964.52 W/m^2, Error = 0.02 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 63.04°C | Condensation Temp: 59.25°C | Vapor Flux: 0.59 kg/m²/hr
#   Stage 2: Evap Temp: 59.25°C | Condensation Temp: 55.10°C | Vapor Flux: 0.57 kg/m²/hr
#   Stage 3: Evap Temp: 55.10°C | Condensation Temp: 50.44°C | Vapor Flux: 0.55 kg/m²/hr
#   Stage 4: Evap Temp: 50.44°C | Condensation Temp: 45.03°C | Vapor Flux: 0.53 kg/m²/hr
#   Stage 5: Evap Temp: 45.03°C | Condensation Temp: 38.48°C | Vapor Flux: 0.52 kg/m²/hr
#   Stage 6: Evap Temp: 38.48°C | Condensation Temp: 30.00°C | Vapor Flux: 0.49 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.25 kg/m²/hr
# Total Efficiency (eta_tot): 205.53%
#
# [22/42] n=8_T=15C
# Warning: Rayleigh number (7.08e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2787.99 W/m^2, Error = 1823.49 W/m^2
# Iteration 2: Calculated q_in,1 = 1595.61 W/m^2, Error = 631.11 W/m^2
# Iteration 3: Calculated q_in,1 = 1278.38 W/m^2, Error = 313.88 W/m^2
# Iteration 4: Calculated q_in,1 = 1145.54 W/m^2, Error = 181.04 W/m^2
# Iteration 5: Calculated q_in,1 = 1077.24 W/m^2, Error = 112.74 W/m^2
# Iteration 6: Calculated q_in,1 = 1037.90 W/m^2, Error = 73.40 W/m^2
# Iteration 7: Calculated q_in,1 = 1013.61 W/m^2, Error = 49.11 W/m^2
# Iteration 8: Calculated q_in,1 = 997.94 W/m^2, Error = 33.44 W/m^2
# Iteration 9: Calculated q_in,1 = 987.54 W/m^2, Error = 23.04 W/m^2
# Iteration 10: Calculated q_in,1 = 980.50 W/m^2, Error = 16.00 W/m^2
# Iteration 11: Calculated q_in,1 = 975.68 W/m^2, Error = 11.18 W/m^2
# Iteration 12: Calculated q_in,1 = 972.33 W/m^2, Error = 7.83 W/m^2
# Iteration 13: Calculated q_in,1 = 970.01 W/m^2, Error = 5.51 W/m^2
# Iteration 14: Calculated q_in,1 = 968.38 W/m^2, Error = 3.88 W/m^2
# Iteration 15: Calculated q_in,1 = 967.23 W/m^2, Error = 2.73 W/m^2
# Iteration 16: Calculated q_in,1 = 966.43 W/m^2, Error = 1.93 W/m^2
# Iteration 17: Calculated q_in,1 = 965.86 W/m^2, Error = 1.36 W/m^2
# Iteration 18: Calculated q_in,1 = 965.46 W/m^2, Error = 0.96 W/m^2
# Iteration 19: Calculated q_in,1 = 965.18 W/m^2, Error = 0.68 W/m^2
# Iteration 20: Calculated q_in,1 = 964.98 W/m^2, Error = 0.48 W/m^2
# Iteration 21: Calculated q_in,1 = 964.84 W/m^2, Error = 0.34 W/m^2
# Iteration 22: Calculated q_in,1 = 964.74 W/m^2, Error = 0.24 W/m^2
# Iteration 23: Calculated q_in,1 = 964.67 W/m^2, Error = 0.17 W/m^2
# Iteration 24: Calculated q_in,1 = 964.62 W/m^2, Error = 0.12 W/m^2
# Iteration 25: Calculated q_in,1 = 964.58 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 50.40°C | Condensation Temp: 47.52°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 2: Evap Temp: 47.52°C | Condensation Temp: 44.72°C | Vapor Flux: 0.24 kg/m²/hr
#   Stage 3: Evap Temp: 44.72°C | Condensation Temp: 42.00°C | Vapor Flux: 0.21 kg/m²/hr
#   Stage 4: Evap Temp: 42.00°C | Condensation Temp: 39.37°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 5: Evap Temp: 39.37°C | Condensation Temp: 36.85°C | Vapor Flux: 0.15 kg/m²/hr
#   Stage 6: Evap Temp: 36.85°C | Condensation Temp: 34.45°C | Vapor Flux: 0.13 kg/m²/hr
#   Stage 7: Evap Temp: 34.45°C | Condensation Temp: 32.16°C | Vapor Flux: 0.11 kg/m²/hr
#   Stage 8: Evap Temp: 32.16°C | Condensation Temp: 30.00°C | Vapor Flux: 0.09 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.39 kg/m²/hr
# Total Efficiency (eta_tot): 87.61%
#
# [23/42] n=8_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2655.10 W/m^2, Error = 1690.60 W/m^2
# Iteration 2: Calculated q_in,1 = 1503.55 W/m^2, Error = 539.05 W/m^2
# Iteration 3: Calculated q_in,1 = 1207.65 W/m^2, Error = 243.15 W/m^2
# Iteration 4: Calculated q_in,1 = 1090.02 W/m^2, Error = 125.52 W/m^2
# Iteration 5: Calculated q_in,1 = 1033.68 W/m^2, Error = 69.18 W/m^2
# Iteration 6: Calculated q_in,1 = 1003.97 W/m^2, Error = 39.47 W/m^2
# Iteration 7: Calculated q_in,1 = 987.46 W/m^2, Error = 22.96 W/m^2
# Iteration 8: Calculated q_in,1 = 978.00 W/m^2, Error = 13.50 W/m^2
# Iteration 9: Calculated q_in,1 = 972.49 W/m^2, Error = 7.99 W/m^2
# Iteration 10: Calculated q_in,1 = 969.25 W/m^2, Error = 4.75 W/m^2
# Iteration 11: Calculated q_in,1 = 967.33 W/m^2, Error = 2.83 W/m^2
# Iteration 12: Calculated q_in,1 = 966.19 W/m^2, Error = 1.69 W/m^2
# Iteration 13: Calculated q_in,1 = 965.51 W/m^2, Error = 1.01 W/m^2
# Iteration 14: Calculated q_in,1 = 965.10 W/m^2, Error = 0.60 W/m^2
# Iteration 15: Calculated q_in,1 = 964.86 W/m^2, Error = 0.36 W/m^2
# Iteration 16: Calculated q_in,1 = 964.71 W/m^2, Error = 0.21 W/m^2
# Iteration 17: Calculated q_in,1 = 964.63 W/m^2, Error = 0.13 W/m^2
# Iteration 18: Calculated q_in,1 = 964.58 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 53.37°C | Condensation Temp: 50.45°C | Vapor Flux: 0.31 kg/m²/hr
#   Stage 2: Evap Temp: 50.45°C | Condensation Temp: 47.55°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 3: Evap Temp: 47.55°C | Condensation Temp: 44.66°C | Vapor Flux: 0.25 kg/m²/hr
#   Stage 4: Evap Temp: 44.66°C | Condensation Temp: 41.78°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 5: Evap Temp: 41.78°C | Condensation Temp: 38.89°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 6: Evap Temp: 38.89°C | Condensation Temp: 35.99°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 7: Evap Temp: 35.99°C | Condensation Temp: 33.04°C | Vapor Flux: 0.16 kg/m²/hr
#   Stage 8: Evap Temp: 33.04°C | Condensation Temp: 30.00°C | Vapor Flux: 0.14 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.73 kg/m²/hr
# Total Efficiency (eta_tot): 109.28%
#
# [24/42] n=8_T=25C
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2524.74 W/m^2, Error = 1560.24 W/m^2
# Iteration 2: Calculated q_in,1 = 1417.32 W/m^2, Error = 452.82 W/m^2
# Iteration 3: Calculated q_in,1 = 1146.34 W/m^2, Error = 181.84 W/m^2
# Iteration 4: Calculated q_in,1 = 1046.61 W/m^2, Error = 82.11 W/m^2
# Iteration 5: Calculated q_in,1 = 1003.53 W/m^2, Error = 39.03 W/m^2
# Iteration 6: Calculated q_in,1 = 983.51 W/m^2, Error = 19.01 W/m^2
# Iteration 7: Calculated q_in,1 = 973.86 W/m^2, Error = 9.36 W/m^2
# Iteration 8: Calculated q_in,1 = 969.14 W/m^2, Error = 4.64 W/m^2
# Iteration 9: Calculated q_in,1 = 966.81 W/m^2, Error = 2.31 W/m^2
# Iteration 10: Calculated q_in,1 = 965.65 W/m^2, Error = 1.15 W/m^2
# Iteration 11: Calculated q_in,1 = 965.07 W/m^2, Error = 0.57 W/m^2
# Iteration 12: Calculated q_in,1 = 964.78 W/m^2, Error = 0.28 W/m^2
# Iteration 13: Calculated q_in,1 = 964.64 W/m^2, Error = 0.14 W/m^2
# Iteration 14: Calculated q_in,1 = 964.57 W/m^2, Error = 0.07 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 56.19°C | Condensation Temp: 53.24°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 2: Evap Temp: 53.24°C | Condensation Temp: 50.25°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 3: Evap Temp: 50.25°C | Condensation Temp: 47.21°C | Vapor Flux: 0.29 kg/m²/hr
#   Stage 4: Evap Temp: 47.21°C | Condensation Temp: 44.10°C | Vapor Flux: 0.27 kg/m²/hr
#   Stage 5: Evap Temp: 44.10°C | Condensation Temp: 40.88°C | Vapor Flux: 0.24 kg/m²/hr
#   Stage 6: Evap Temp: 40.88°C | Condensation Temp: 37.51°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 7: Evap Temp: 37.51°C | Condensation Temp: 33.91°C | Vapor Flux: 0.21 kg/m²/hr
#   Stage 8: Evap Temp: 33.91°C | Condensation Temp: 30.00°C | Vapor Flux: 0.19 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.10 kg/m²/hr
# Total Efficiency (eta_tot): 132.36%
#
# [25/42] n=8_T=30C
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2396.88 W/m^2, Error = 1432.38 W/m^2
# Iteration 2: Calculated q_in,1 = 1337.24 W/m^2, Error = 372.74 W/m^2
# Iteration 3: Calculated q_in,1 = 1094.63 W/m^2, Error = 130.13 W/m^2
# Iteration 4: Calculated q_in,1 = 1014.46 W/m^2, Error = 49.96 W/m^2
# Iteration 5: Calculated q_in,1 = 984.39 W/m^2, Error = 19.89 W/m^2
# Iteration 6: Calculated q_in,1 = 972.53 W/m^2, Error = 8.03 W/m^2
# Iteration 7: Calculated q_in,1 = 967.76 W/m^2, Error = 3.26 W/m^2
# Iteration 8: Calculated q_in,1 = 965.83 W/m^2, Error = 1.33 W/m^2
# Iteration 9: Calculated q_in,1 = 965.04 W/m^2, Error = 0.54 W/m^2
# Iteration 10: Calculated q_in,1 = 964.72 W/m^2, Error = 0.22 W/m^2
# Iteration 11: Calculated q_in,1 = 964.59 W/m^2, Error = 0.09 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 58.88°C | Condensation Temp: 55.89°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 2: Evap Temp: 55.89°C | Condensation Temp: 52.82°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 3: Evap Temp: 52.82°C | Condensation Temp: 49.65°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 4: Evap Temp: 49.65°C | Condensation Temp: 46.33°C | Vapor Flux: 0.31 kg/m²/hr
#   Stage 5: Evap Temp: 46.33°C | Condensation Temp: 42.80°C | Vapor Flux: 0.29 kg/m²/hr
#   Stage 6: Evap Temp: 42.80°C | Condensation Temp: 39.00°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 7: Evap Temp: 39.00°C | Condensation Temp: 34.80°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 8: Evap Temp: 34.80°C | Condensation Temp: 30.00°C | Vapor Flux: 0.25 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.48 kg/m²/hr
# Total Efficiency (eta_tot): 156.75%
#
# [26/42] n=8_T=35C
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2271.41 W/m^2, Error = 1306.91 W/m^2
# Iteration 2: Calculated q_in,1 = 1263.70 W/m^2, Error = 299.20 W/m^2
# Iteration 3: Calculated q_in,1 = 1052.53 W/m^2, Error = 88.03 W/m^2
# Iteration 4: Calculated q_in,1 = 992.23 W/m^2, Error = 27.73 W/m^2
# Iteration 5: Calculated q_in,1 = 973.42 W/m^2, Error = 8.92 W/m^2
# Iteration 6: Calculated q_in,1 = 967.39 W/m^2, Error = 2.89 W/m^2
# Iteration 7: Calculated q_in,1 = 965.44 W/m^2, Error = 0.94 W/m^2
# Iteration 8: Calculated q_in,1 = 964.81 W/m^2, Error = 0.31 W/m^2
# Iteration 9: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 61.45°C | Condensation Temp: 58.42°C | Vapor Flux: 0.44 kg/m²/hr
#   Stage 2: Evap Temp: 58.42°C | Condensation Temp: 55.28°C | Vapor Flux: 0.41 kg/m²/hr
#   Stage 3: Evap Temp: 55.28°C | Condensation Temp: 51.98°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 4: Evap Temp: 51.98°C | Condensation Temp: 48.46°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 5: Evap Temp: 48.46°C | Condensation Temp: 44.66°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 6: Evap Temp: 44.66°C | Condensation Temp: 40.46°C | Vapor Flux: 0.33 kg/m²/hr
#   Stage 7: Evap Temp: 40.46°C | Condensation Temp: 35.67°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 8: Evap Temp: 35.67°C | Condensation Temp: 30.00°C | Vapor Flux: 0.30 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.89 kg/m²/hr
# Total Efficiency (eta_tot): 182.34%
#
# [27/42] n=8_T=40C
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2148.16 W/m^2, Error = 1183.66 W/m^2
# Iteration 2: Calculated q_in,1 = 1197.17 W/m^2, Error = 232.67 W/m^2
# Iteration 3: Calculated q_in,1 = 1019.84 W/m^2, Error = 55.34 W/m^2
# Iteration 4: Calculated q_in,1 = 978.16 W/m^2, Error = 13.66 W/m^2
# Iteration 5: Calculated q_in,1 = 967.90 W/m^2, Error = 3.40 W/m^2
# Iteration 6: Calculated q_in,1 = 965.35 W/m^2, Error = 0.85 W/m^2
# Iteration 7: Calculated q_in,1 = 964.71 W/m^2, Error = 0.21 W/m^2
# Iteration 8: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 63.90°C | Condensation Temp: 60.83°C | Vapor Flux: 0.48 kg/m²/hr
#   Stage 2: Evap Temp: 60.83°C | Condensation Temp: 57.61°C | Vapor Flux: 0.46 kg/m²/hr
#   Stage 3: Evap Temp: 57.61°C | Condensation Temp: 54.20°C | Vapor Flux: 0.44 kg/m²/hr
#   Stage 4: Evap Temp: 54.20°C | Condensation Temp: 50.51°C | Vapor Flux: 0.42 kg/m²/hr
#   Stage 5: Evap Temp: 50.51°C | Condensation Temp: 46.46°C | Vapor Flux: 0.40 kg/m²/hr
#   Stage 6: Evap Temp: 46.46°C | Condensation Temp: 41.88°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 7: Evap Temp: 41.88°C | Condensation Temp: 36.54°C | Vapor Flux: 0.37 kg/m²/hr
#   Stage 8: Evap Temp: 36.54°C | Condensation Temp: 30.00°C | Vapor Flux: 0.36 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.31 kg/m²/hr
# Total Efficiency (eta_tot): 209.00%
#
# [28/42] n=8_T=45C
# Warning: Rayleigh number (1.91e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 8 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2026.75 W/m^2, Error = 1062.25 W/m^2
# Iteration 2: Calculated q_in,1 = 1138.30 W/m^2, Error = 173.80 W/m^2
# Iteration 3: Calculated q_in,1 = 996.08 W/m^2, Error = 31.58 W/m^2
# Iteration 4: Calculated q_in,1 = 970.25 W/m^2, Error = 5.75 W/m^2
# Iteration 5: Calculated q_in,1 = 965.55 W/m^2, Error = 1.05 W/m^2
# Iteration 6: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 7: Calculated q_in,1 = 964.53 W/m^2, Error = 0.03 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 66.23°C | Condensation Temp: 63.13°C | Vapor Flux: 0.53 kg/m²/hr
#   Stage 2: Evap Temp: 63.13°C | Condensation Temp: 59.84°C | Vapor Flux: 0.51 kg/m²/hr
#   Stage 3: Evap Temp: 59.84°C | Condensation Temp: 56.32°C | Vapor Flux: 0.49 kg/m²/hr
#   Stage 4: Evap Temp: 56.32°C | Condensation Temp: 52.47°C | Vapor Flux: 0.47 kg/m²/hr
#   Stage 5: Evap Temp: 52.47°C | Condensation Temp: 48.19°C | Vapor Flux: 0.46 kg/m²/hr
#   Stage 6: Evap Temp: 48.19°C | Condensation Temp: 43.27°C | Vapor Flux: 0.45 kg/m²/hr
#   Stage 7: Evap Temp: 43.27°C | Condensation Temp: 37.40°C | Vapor Flux: 0.43 kg/m²/hr
#   Stage 8: Evap Temp: 37.40°C | Condensation Temp: 30.00°C | Vapor Flux: 0.42 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.75 kg/m²/hr
# Total Efficiency (eta_tot): 236.68%
#
# [29/42] n=10_T=15C
# Warning: Rayleigh number (7.08e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 10 Stages ---
#
# Iteration 1: Calculated q_in,1 = 3088.32 W/m^2, Error = 2123.82 W/m^2
# Iteration 2: Calculated q_in,1 = 1740.38 W/m^2, Error = 775.88 W/m^2
# Iteration 3: Calculated q_in,1 = 1373.87 W/m^2, Error = 409.37 W/m^2
# Iteration 4: Calculated q_in,1 = 1217.38 W/m^2, Error = 252.88 W/m^2
# Iteration 5: Calculated q_in,1 = 1134.70 W/m^2, Error = 170.20 W/m^2
# Iteration 6: Calculated q_in,1 = 1085.17 W/m^2, Error = 120.67 W/m^2
# Iteration 7: Calculated q_in,1 = 1053.03 W/m^2, Error = 88.53 W/m^2
# Iteration 8: Calculated q_in,1 = 1030.98 W/m^2, Error = 66.48 W/m^2
# Iteration 9: Calculated q_in,1 = 1015.27 W/m^2, Error = 50.77 W/m^2
# Iteration 10: Calculated q_in,1 = 1003.75 W/m^2, Error = 39.25 W/m^2
# Iteration 11: Calculated q_in,1 = 995.13 W/m^2, Error = 30.63 W/m^2
# Iteration 12: Calculated q_in,1 = 988.57 W/m^2, Error = 24.07 W/m^2
# Iteration 13: Calculated q_in,1 = 983.51 W/m^2, Error = 19.01 W/m^2
# Iteration 14: Calculated q_in,1 = 979.58 W/m^2, Error = 15.08 W/m^2
# Iteration 15: Calculated q_in,1 = 976.51 W/m^2, Error = 12.01 W/m^2
# Iteration 16: Calculated q_in,1 = 974.08 W/m^2, Error = 9.58 W/m^2
# Iteration 17: Calculated q_in,1 = 972.16 W/m^2, Error = 7.66 W/m^2
# Iteration 18: Calculated q_in,1 = 970.64 W/m^2, Error = 6.14 W/m^2
# Iteration 19: Calculated q_in,1 = 969.42 W/m^2, Error = 4.92 W/m^2
# Iteration 20: Calculated q_in,1 = 968.45 W/m^2, Error = 3.95 W/m^2
# Iteration 21: Calculated q_in,1 = 967.67 W/m^2, Error = 3.17 W/m^2
# Iteration 22: Calculated q_in,1 = 967.05 W/m^2, Error = 2.55 W/m^2
# Iteration 23: Calculated q_in,1 = 966.55 W/m^2, Error = 2.05 W/m^2
# Iteration 24: Calculated q_in,1 = 966.15 W/m^2, Error = 1.65 W/m^2
# Iteration 25: Calculated q_in,1 = 965.83 W/m^2, Error = 1.33 W/m^2
# Iteration 26: Calculated q_in,1 = 965.57 W/m^2, Error = 1.07 W/m^2
# Iteration 27: Calculated q_in,1 = 965.36 W/m^2, Error = 0.86 W/m^2
# Iteration 28: Calculated q_in,1 = 965.20 W/m^2, Error = 0.70 W/m^2
# Iteration 29: Calculated q_in,1 = 965.06 W/m^2, Error = 0.56 W/m^2
# Iteration 30: Calculated q_in,1 = 964.95 W/m^2, Error = 0.45 W/m^2
# Iteration 31: Calculated q_in,1 = 964.86 W/m^2, Error = 0.36 W/m^2
# Iteration 32: Calculated q_in,1 = 964.79 W/m^2, Error = 0.29 W/m^2
# Iteration 33: Calculated q_in,1 = 964.74 W/m^2, Error = 0.24 W/m^2
# Iteration 34: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 35: Calculated q_in,1 = 964.65 W/m^2, Error = 0.15 W/m^2
# Iteration 36: Calculated q_in,1 = 964.62 W/m^2, Error = 0.12 W/m^2
# Iteration 37: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 50.90°C | Condensation Temp: 48.16°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 2: Evap Temp: 48.16°C | Condensation Temp: 45.53°C | Vapor Flux: 0.23 kg/m²/hr
#   Stage 3: Evap Temp: 45.53°C | Condensation Temp: 43.01°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 4: Evap Temp: 43.01°C | Condensation Temp: 40.62°C | Vapor Flux: 0.17 kg/m²/hr
#   Stage 5: Evap Temp: 40.62°C | Condensation Temp: 38.39°C | Vapor Flux: 0.14 kg/m²/hr
#   Stage 6: Evap Temp: 38.39°C | Condensation Temp: 36.32°C | Vapor Flux: 0.12 kg/m²/hr
#   Stage 7: Evap Temp: 36.32°C | Condensation Temp: 34.44°C | Vapor Flux: 0.10 kg/m²/hr
#   Stage 8: Evap Temp: 34.44°C | Condensation Temp: 32.75°C | Vapor Flux: 0.08 kg/m²/hr
#   Stage 9: Evap Temp: 32.75°C | Condensation Temp: 31.27°C | Vapor Flux: 0.06 kg/m²/hr
#   Stage 10: Evap Temp: 31.27°C | Condensation Temp: 30.00°C | Vapor Flux: 0.05 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.39 kg/m²/hr
# Total Efficiency (eta_tot): 87.83%
#
# [30/42] n=10_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 10 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2939.16 W/m^2, Error = 1974.66 W/m^2
# Iteration 2: Calculated q_in,1 = 1630.58 W/m^2, Error = 666.08 W/m^2
# Iteration 3: Calculated q_in,1 = 1283.58 W/m^2, Error = 319.08 W/m^2
# Iteration 4: Calculated q_in,1 = 1141.13 W/m^2, Error = 176.63 W/m^2
# Iteration 5: Calculated q_in,1 = 1069.86 W/m^2, Error = 105.36 W/m^2
# Iteration 6: Calculated q_in,1 = 1030.07 W/m^2, Error = 65.57 W/m^2
# Iteration 7: Calculated q_in,1 = 1006.36 W/m^2, Error = 41.86 W/m^2
# Iteration 8: Calculated q_in,1 = 991.65 W/m^2, Error = 27.15 W/m^2
# Iteration 9: Calculated q_in,1 = 982.29 W/m^2, Error = 17.79 W/m^2
# Iteration 10: Calculated q_in,1 = 976.24 W/m^2, Error = 11.74 W/m^2
# Iteration 11: Calculated q_in,1 = 972.28 W/m^2, Error = 7.78 W/m^2
# Iteration 12: Calculated q_in,1 = 969.67 W/m^2, Error = 5.17 W/m^2
# Iteration 13: Calculated q_in,1 = 967.94 W/m^2, Error = 3.44 W/m^2
# Iteration 14: Calculated q_in,1 = 966.79 W/m^2, Error = 2.29 W/m^2
# Iteration 15: Calculated q_in,1 = 966.03 W/m^2, Error = 1.53 W/m^2
# Iteration 16: Calculated q_in,1 = 965.52 W/m^2, Error = 1.02 W/m^2
# Iteration 17: Calculated q_in,1 = 965.18 W/m^2, Error = 0.68 W/m^2
# Iteration 18: Calculated q_in,1 = 964.95 W/m^2, Error = 0.45 W/m^2
# Iteration 19: Calculated q_in,1 = 964.80 W/m^2, Error = 0.30 W/m^2
# Iteration 20: Calculated q_in,1 = 964.70 W/m^2, Error = 0.20 W/m^2
# Iteration 21: Calculated q_in,1 = 964.64 W/m^2, Error = 0.14 W/m^2
# Iteration 22: Calculated q_in,1 = 964.59 W/m^2, Error = 0.09 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 54.15°C | Condensation Temp: 51.44°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 2: Evap Temp: 51.44°C | Condensation Temp: 48.79°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 3: Evap Temp: 48.79°C | Condensation Temp: 46.19°C | Vapor Flux: 0.23 kg/m²/hr
#   Stage 4: Evap Temp: 46.19°C | Condensation Temp: 43.67°C | Vapor Flux: 0.20 kg/m²/hr
# ...
# Iteration 88: Calculated q_in,1 = 964.62 W/m^2, Error = 0.12 W/m^2
# Iteration 89: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 90: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 91: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 51.09°C | Condensation Temp: 48.41°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 2: Evap Temp: 48.41°C | Condensation Temp: 45.83°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 3: Evap Temp: 45.83°C | Condensation Temp: 43.39°C | Vapor Flux: 0.19 kg/m²/hr
#   Stage 4: Evap Temp: 43.39°C | Condensation Temp: 41.09°C | Vapor Flux: 0.16 kg/m²/hr
#   Stage 5: Evap Temp: 41.09°C | Condensation Temp: 38.96°C | Vapor Flux: 0.13 kg/m²/hr
#   Stage 6: Evap Temp: 38.96°C | Condensation Temp: 37.01°C | Vapor Flux: 0.11 kg/m²/hr
#   Stage 7: Evap Temp: 37.01°C | Condensation Temp: 35.26°C | Vapor Flux: 0.09 kg/m²/hr
#   Stage 8: Evap Temp: 35.26°C | Condensation Temp: 33.73°C | Vapor Flux: 0.07 kg/m²/hr
#   Stage 9: Evap Temp: 33.73°C | Condensation Temp: 32.43°C | Vapor Flux: 0.05 kg/m²/hr
#   Stage 10: Evap Temp: 32.43°C | Condensation Temp: 31.37°C | Vapor Flux: 0.04 kg/m²/hr
#   Stage 11: Evap Temp: 31.37°C | Condensation Temp: 30.56°C | Vapor Flux: 0.02 kg/m²/hr
#   Stage 12: Evap Temp: 30.56°C | Condensation Temp: 30.00°C | Vapor Flux: 0.01 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.37 kg/m²/hr
# Total Efficiency (eta_tot): 86.29%
#
# [37/42] n=12_T=20C
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 3227.38 W/m^2, Error = 2262.88 W/m^2
# Iteration 2: Calculated q_in,1 = 1766.39 W/m^2, Error = 801.89 W/m^2
# Iteration 3: Calculated q_in,1 = 1369.81 W/m^2, Error = 405.31 W/m^2
# Iteration 4: Calculated q_in,1 = 1203.41 W/m^2, Error = 238.91 W/m^2
# Iteration 5: Calculated q_in,1 = 1117.62 W/m^2, Error = 153.12 W/m^2
# Iteration 6: Calculated q_in,1 = 1067.70 W/m^2, Error = 103.20 W/m^2
# Iteration 7: Calculated q_in,1 = 1036.32 W/m^2, Error = 71.82 W/m^2
# Iteration 8: Calculated q_in,1 = 1015.56 W/m^2, Error = 51.06 W/m^2
# Iteration 9: Calculated q_in,1 = 1001.34 W/m^2, Error = 36.84 W/m^2
# Iteration 10: Calculated q_in,1 = 991.36 W/m^2, Error = 26.86 W/m^2
# Iteration 11: Calculated q_in,1 = 984.23 W/m^2, Error = 19.73 W/m^2
# Iteration 12: Calculated q_in,1 = 979.07 W/m^2, Error = 14.57 W/m^2
# Iteration 13: Calculated q_in,1 = 975.31 W/m^2, Error = 10.81 W/m^2
# Iteration 14: Calculated q_in,1 = 972.54 W/m^2, Error = 8.04 W/m^2
# Iteration 15: Calculated q_in,1 = 970.49 W/m^2, Error = 5.99 W/m^2
# Iteration 16: Calculated q_in,1 = 968.97 W/m^2, Error = 4.47 W/m^2
# Iteration 17: Calculated q_in,1 = 967.84 W/m^2, Error = 3.34 W/m^2
# Iteration 18: Calculated q_in,1 = 967.00 W/m^2, Error = 2.50 W/m^2
# Iteration 19: Calculated q_in,1 = 966.37 W/m^2, Error = 1.87 W/m^2
# Iteration 20: Calculated q_in,1 = 965.90 W/m^2, Error = 1.40 W/m^2
# Iteration 21: Calculated q_in,1 = 965.55 W/m^2, Error = 1.05 W/m^2
# Iteration 22: Calculated q_in,1 = 965.29 W/m^2, Error = 0.79 W/m^2
# Iteration 23: Calculated q_in,1 = 965.09 W/m^2, Error = 0.59 W/m^2
# Iteration 24: Calculated q_in,1 = 964.94 W/m^2, Error = 0.44 W/m^2
# Iteration 25: Calculated q_in,1 = 964.83 W/m^2, Error = 0.33 W/m^2
# Iteration 26: Calculated q_in,1 = 964.75 W/m^2, Error = 0.25 W/m^2
# Iteration 27: Calculated q_in,1 = 964.69 W/m^2, Error = 0.19 W/m^2
# Iteration 28: Calculated q_in,1 = 964.64 W/m^2, Error = 0.14 W/m^2
# Iteration 29: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
# Iteration 30: Calculated q_in,1 = 964.58 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 54.56°C | Condensation Temp: 51.95°C | Vapor Flux: 0.29 kg/m²/hr
#   Stage 2: Evap Temp: 51.95°C | Condensation Temp: 49.42°C | Vapor Flux: 0.25 kg/m²/hr
#   Stage 3: Evap Temp: 49.42°C | Condensation Temp: 46.98°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 4: Evap Temp: 46.98°C | Condensation Temp: 44.62°C | Vapor Flux: 0.19 kg/m²/hr
#   Stage 5: Evap Temp: 44.62°C | Condensation Temp: 42.37°C | Vapor Flux: 0.17 kg/m²/hr
#   Stage 6: Evap Temp: 42.37°C | Condensation Temp: 40.23°C | Vapor Flux: 0.14 kg/m²/hr
#   Stage 7: Evap Temp: 40.23°C | Condensation Temp: 38.21°C | Vapor Flux: 0.12 kg/m²/hr
#   Stage 8: Evap Temp: 38.21°C | Condensation Temp: 36.32°C | Vapor Flux: 0.10 kg/m²/hr
#   Stage 9: Evap Temp: 36.32°C | Condensation Temp: 34.55°C | Vapor Flux: 0.09 kg/m²/hr
#   Stage 10: Evap Temp: 34.55°C | Condensation Temp: 32.90°C | Vapor Flux: 0.07 kg/m²/hr
#   Stage 11: Evap Temp: 32.90°C | Condensation Temp: 31.39°C | Vapor Flux: 0.06 kg/m²/hr
#   Stage 12: Evap Temp: 31.39°C | Condensation Temp: 30.00°C | Vapor Flux: 0.05 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.76 kg/m²/hr
# Total Efficiency (eta_tot): 111.39%
#
# [38/42] n=12_T=25C
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 3064.14 W/m^2, Error = 2099.64 W/m^2
# Iteration 2: Calculated q_in,1 = 1644.55 W/m^2, Error = 680.05 W/m^2
# Iteration 3: Calculated q_in,1 = 1270.26 W/m^2, Error = 305.76 W/m^2
# Iteration 4: Calculated q_in,1 = 1121.53 W/m^2, Error = 157.03 W/m^2
# Iteration 5: Calculated q_in,1 = 1050.75 W/m^2, Error = 86.25 W/m^2
# Iteration 6: Calculated q_in,1 = 1013.63 W/m^2, Error = 49.13 W/m^2
# Iteration 7: Calculated q_in,1 = 993.07 W/m^2, Error = 28.57 W/m^2
# Iteration 8: Calculated q_in,1 = 981.32 W/m^2, Error = 16.82 W/m^2
# Iteration 9: Calculated q_in,1 = 974.47 W/m^2, Error = 9.97 W/m^2
# Iteration 10: Calculated q_in,1 = 970.43 W/m^2, Error = 5.93 W/m^2
# Iteration 11: Calculated q_in,1 = 968.04 W/m^2, Error = 3.54 W/m^2
# Iteration 12: Calculated q_in,1 = 966.61 W/m^2, Error = 2.11 W/m^2
# Iteration 13: Calculated q_in,1 = 965.76 W/m^2, Error = 1.26 W/m^2
# Iteration 14: Calculated q_in,1 = 965.26 W/m^2, Error = 0.76 W/m^2
# Iteration 15: Calculated q_in,1 = 964.95 W/m^2, Error = 0.45 W/m^2
# Iteration 16: Calculated q_in,1 = 964.77 W/m^2, Error = 0.27 W/m^2
# Iteration 17: Calculated q_in,1 = 964.66 W/m^2, Error = 0.16 W/m^2
# Iteration 18: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 57.90°C | Condensation Temp: 55.36°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 2: Evap Temp: 55.36°C | Condensation Temp: 52.86°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 3: Evap Temp: 52.86°C | Condensation Temp: 50.40°C | Vapor Flux: 0.25 kg/m²/hr
#   Stage 4: Evap Temp: 50.40°C | Condensation Temp: 48.00°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 5: Evap Temp: 48.00°C | Condensation Temp: 45.64°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 6: Evap Temp: 45.64°C | Condensation Temp: 43.33°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 7: Evap Temp: 43.33°C | Condensation Temp: 41.06°C | Vapor Flux: 0.16 kg/m²/hr
#   Stage 8: Evap Temp: 41.06°C | Condensation Temp: 38.83°C | Vapor Flux: 0.14 kg/m²/hr
#   Stage 9: Evap Temp: 38.83°C | Condensation Temp: 36.63°C | Vapor Flux: 0.13 kg/m²/hr
#   Stage 10: Evap Temp: 36.63°C | Condensation Temp: 34.44°C | Vapor Flux: 0.12 kg/m²/hr
#   Stage 11: Evap Temp: 34.44°C | Condensation Temp: 32.24°C | Vapor Flux: 0.11 kg/m²/hr
#   Stage 12: Evap Temp: 32.24°C | Condensation Temp: 30.00°C | Vapor Flux: 0.10 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.20 kg/m²/hr
# Total Efficiency (eta_tot): 138.91%
#
# [39/42] n=12_T=30C
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2903.16 W/m^2, Error = 1938.66 W/m^2
# Iteration 2: Calculated q_in,1 = 1530.16 W/m^2, Error = 565.66 W/m^2
# Iteration 3: Calculated q_in,1 = 1184.65 W/m^2, Error = 220.15 W/m^2
# Iteration 4: Calculated q_in,1 = 1059.43 W/m^2, Error = 94.93 W/m^2
# Iteration 5: Calculated q_in,1 = 1007.32 W/m^2, Error = 42.82 W/m^2
# Iteration 6: Calculated q_in,1 = 984.22 W/m^2, Error = 19.72 W/m^2
# Iteration 7: Calculated q_in,1 = 973.67 W/m^2, Error = 9.17 W/m^2
# Iteration 8: Calculated q_in,1 = 968.78 W/m^2, Error = 4.28 W/m^2
# Iteration 9: Calculated q_in,1 = 966.50 W/m^2, Error = 2.00 W/m^2
# Iteration 10: Calculated q_in,1 = 965.44 W/m^2, Error = 0.94 W/m^2
# Iteration 11: Calculated q_in,1 = 964.94 W/m^2, Error = 0.44 W/m^2
# Iteration 12: Calculated q_in,1 = 964.71 W/m^2, Error = 0.21 W/m^2
# Iteration 13: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 61.13°C | Condensation Temp: 58.63°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 2: Evap Temp: 58.63°C | Condensation Temp: 56.14°C | Vapor Flux: 0.31 kg/m²/hr
#   Stage 3: Evap Temp: 56.14°C | Condensation Temp: 53.68°C | Vapor Flux: 0.29 kg/m²/hr
#   Stage 4: Evap Temp: 53.68°C | Condensation Temp: 51.22°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 5: Evap Temp: 51.22°C | Condensation Temp: 48.76°C | Vapor Flux: 0.24 kg/m²/hr
#   Stage 6: Evap Temp: 48.76°C | Condensation Temp: 46.30°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 7: Evap Temp: 46.30°C | Condensation Temp: 43.81°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 8: Evap Temp: 43.81°C | Condensation Temp: 41.28°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 9: Evap Temp: 41.28°C | Condensation Temp: 38.68°C | Vapor Flux: 0.17 kg/m²/hr
#   Stage 10: Evap Temp: 38.68°C | Condensation Temp: 35.98°C | Vapor Flux: 0.16 kg/m²/hr
#   Stage 11: Evap Temp: 35.98°C | Condensation Temp: 33.11°C | Vapor Flux: 0.15 kg/m²/hr
#   Stage 12: Evap Temp: 33.11°C | Condensation Temp: 30.00°C | Vapor Flux: 0.15 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.67 kg/m²/hr
# Total Efficiency (eta_tot): 168.81%
#
# [40/42] n=12_T=35C
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2744.17 W/m^2, Error = 1779.67 W/m^2
# Iteration 2: Calculated q_in,1 = 1423.85 W/m^2, Error = 459.35 W/m^2
# Iteration 3: Calculated q_in,1 = 1113.71 W/m^2, Error = 149.21 W/m^2
# Iteration 4: Calculated q_in,1 = 1016.00 W/m^2, Error = 51.50 W/m^2
# Iteration 5: Calculated q_in,1 = 982.64 W/m^2, Error = 18.14 W/m^2
# Iteration 6: Calculated q_in,1 = 970.94 W/m^2, Error = 6.44 W/m^2
# Iteration 7: Calculated q_in,1 = 966.79 W/m^2, Error = 2.29 W/m^2
# Iteration 8: Calculated q_in,1 = 965.32 W/m^2, Error = 0.82 W/m^2
# Iteration 9: Calculated q_in,1 = 964.79 W/m^2, Error = 0.29 W/m^2
# Iteration 10: Calculated q_in,1 = 964.60 W/m^2, Error = 0.10 W/m^2
# Iteration 11: Calculated q_in,1 = 964.54 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 64.23°C | Condensation Temp: 61.76°C | Vapor Flux: 0.38 kg/m²/hr
#   Stage 2: Evap Temp: 61.76°C | Condensation Temp: 59.29°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 3: Evap Temp: 59.29°C | Condensation Temp: 56.80°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 4: Evap Temp: 56.80°C | Condensation Temp: 54.29°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 5: Evap Temp: 54.29°C | Condensation Temp: 51.74°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 6: Evap Temp: 51.74°C | Condensation Temp: 49.14°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 7: Evap Temp: 49.14°C | Condensation Temp: 46.45°C | Vapor Flux: 0.24 kg/m²/hr
#   Stage 8: Evap Temp: 46.45°C | Condensation Temp: 43.65°C | Vapor Flux: 0.23 kg/m²/hr
#   Stage 9: Evap Temp: 43.65°C | Condensation Temp: 40.69°C | Vapor Flux: 0.22 kg/m²/hr
#   Stage 10: Evap Temp: 40.69°C | Condensation Temp: 37.50°C | Vapor Flux: 0.21 kg/m²/hr
#   Stage 11: Evap Temp: 37.50°C | Condensation Temp: 33.98°C | Vapor Flux: 0.20 kg/m²/hr
#   Stage 12: Evap Temp: 33.98°C | Condensation Temp: 30.00°C | Vapor Flux: 0.20 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.18 kg/m²/hr
# Total Efficiency (eta_tot): 201.03%
#
# [41/42] n=12_T=40C
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2586.71 W/m^2, Error = 1622.21 W/m^2
# Iteration 2: Calculated q_in,1 = 1326.40 W/m^2, Error = 361.90 W/m^2
# Iteration 3: Calculated q_in,1 = 1057.77 W/m^2, Error = 93.27 W/m^2
# Iteration 4: Calculated q_in,1 = 988.68 W/m^2, Error = 24.18 W/m^2
# Iteration 5: Calculated q_in,1 = 970.75 W/m^2, Error = 6.25 W/m^2
# Iteration 6: Calculated q_in,1 = 966.11 W/m^2, Error = 1.61 W/m^2
# Iteration 7: Calculated q_in,1 = 964.92 W/m^2, Error = 0.42 W/m^2
# Iteration 8: Calculated q_in,1 = 964.61 W/m^2, Error = 0.11 W/m^2
# Iteration 9: Calculated q_in,1 = 964.53 W/m^2, Error = 0.03 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 67.21°C | Condensation Temp: 64.77°C | Vapor Flux: 0.41 kg/m²/hr
#   Stage 2: Evap Temp: 64.77°C | Condensation Temp: 62.30°C | Vapor Flux: 0.39 kg/m²/hr
#   Stage 3: Evap Temp: 62.30°C | Condensation Temp: 59.80°C | Vapor Flux: 0.36 kg/m²/hr
#   Stage 4: Evap Temp: 59.80°C | Condensation Temp: 57.23°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 5: Evap Temp: 57.23°C | Condensation Temp: 54.60°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 6: Evap Temp: 54.60°C | Condensation Temp: 51.87°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 7: Evap Temp: 51.87°C | Condensation Temp: 49.00°C | Vapor Flux: 0.29 kg/m²/hr
#   Stage 8: Evap Temp: 49.00°C | Condensation Temp: 45.95°C | Vapor Flux: 0.28 kg/m²/hr
#   Stage 9: Evap Temp: 45.95°C | Condensation Temp: 42.65°C | Vapor Flux: 0.27 kg/m²/hr
#   Stage 10: Evap Temp: 42.65°C | Condensation Temp: 39.01°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 11: Evap Temp: 39.01°C | Condensation Temp: 34.87°C | Vapor Flux: 0.26 kg/m²/hr
#   Stage 12: Evap Temp: 34.87°C | Condensation Temp: 30.00°C | Vapor Flux: 0.25 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.73 kg/m²/hr
# Total Efficiency (eta_tot): 235.61%
#
# [42/42] n=12_T=45C
# Warning: Rayleigh number (1.91e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 12 Stages ---
#
# Iteration 1: Calculated q_in,1 = 2429.86 W/m^2, Error = 1465.36 W/m^2
# Iteration 2: Calculated q_in,1 = 1238.83 W/m^2, Error = 274.33 W/m^2
# Iteration 3: Calculated q_in,1 = 1016.64 W/m^2, Error = 52.14 W/m^2
# Iteration 4: Calculated q_in,1 = 973.79 W/m^2, Error = 9.29 W/m^2
# Iteration 5: Calculated q_in,1 = 966.12 W/m^2, Error = 1.62 W/m^2
# Iteration 6: Calculated q_in,1 = 964.78 W/m^2, Error = 0.28 W/m^2
# Iteration 7: Calculated q_in,1 = 964.55 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 70.10°C | Condensation Temp: 67.68°C | Vapor Flux: 0.45 kg/m²/hr
#   Stage 2: Evap Temp: 67.68°C | Condensation Temp: 65.21°C | Vapor Flux: 0.43 kg/m²/hr
#   Stage 3: Evap Temp: 65.21°C | Condensation Temp: 62.67°C | Vapor Flux: 0.40 kg/m²/hr
#   Stage 4: Evap Temp: 62.67°C | Condensation Temp: 60.06°C | Vapor Flux: 0.38 kg/m²/hr
#   Stage 5: Evap Temp: 60.06°C | Condensation Temp: 57.34°C | Vapor Flux: 0.37 kg/m²/hr
#   Stage 6: Evap Temp: 57.34°C | Condensation Temp: 54.49°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 7: Evap Temp: 54.49°C | Condensation Temp: 51.45°C | Vapor Flux: 0.34 kg/m²/hr
#   Stage 8: Evap Temp: 51.45°C | Condensation Temp: 48.18°C | Vapor Flux: 0.33 kg/m²/hr
#   Stage 9: Evap Temp: 48.18°C | Condensation Temp: 44.57°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 10: Evap Temp: 44.57°C | Condensation Temp: 40.50°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 11: Evap Temp: 40.50°C | Condensation Temp: 35.76°C | Vapor Flux: 0.31 kg/m²/hr
#   Stage 12: Evap Temp: 35.76°C | Condensation Temp: 30.00°C | Vapor Flux: 0.31 kg/m²/hr
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.32 kg/m²/hr
# Total Efficiency (eta_tot): 272.60%
#
#
#  All simulations complete. Results saved to 'results\No_cover_FigS15b_simulation_summary_20251225_195511_outdoor.csv'
