# %%
import numpy as np
from scipy.optimize import fsolve
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# # PMMA + air

# %%
# --- Input Parameters ---
params = {
    "q_sun": 1000,            # Incident solar flux (W/m^2)
    "Tr": 0.8495,             # PMMA solar weighted transmittance (84.95%)
    "ref_abs": 0.9645,        # Solar absorber's reflectance (3.55%)
    "condition": 'outdoor',  
    "T_amb_c": 25,           # Ambient air temperature (Celsius)
    "T_b_c": 30,             # Back wall temperature (Celsius), set to be 5C higher than ambient
    "a": 0.05,               # Device width (m)
    "b": 0.0035,              # Unit stage thickness (m)
    "t_ins": 0.01,           # Insulation thickness (m)
    "t_pmma": 0.003,         # PMMA thickness (m)
    "t_air": 0.006,          # air thickness (m)
    "D_a": 3.0e-5,           # Diffusivity of vapor in air (m²/s)
    "k_ins": 0.04,               # Thermal conductivity of insulation (W/mK)
    "k_air": 0.026,          # Thermal conductivity of air (W/mK)
    "k_pmma": 0.18,           # Thermal conductivity of aerogel (W/mK)
    "Pr": 0.71,              # Prandtl number for air 
    "epsilon": 0.95,         # Emissivity of the solar absorber (CNT: 0.95, SSA: 0.03)
    "h_fg": 2357e3,          # Latent heat of vaporization (J/kg, converted from kJ/kg)
    "M_water": 0.018015,     # Molar mass of water (kg/mol)
    "R_gas": 8.314,          # Universal gas constant (J/(mol*K))
    "sigma": 5.67e-8         # Stefan-Boltzmann constant (W/m²K⁴)
}

# %%
# Obtain convective heat transfer coefficient (h_a)    
def get_air_properties(T_amb_c):
    T_amb_k = T_amb_c + 273.15
     # Density using ideal gas law at 1 atm (101325 Pa)
    P_atm = 101325  
    R_air = 287.05  # J/(kg·K) - specific gas constant for air
    rho = P_atm / (R_air * T_amb_k)  # kg/m³

    # Dynamic viscosity using Sutherland's formula
    T_ref = 273.15
    mu_ref = 1.716e-5  # Pa·s at T_ref       
    S = 110.4  # K (Sutherland constant for air)
    mu = mu_ref * (T_amb_k / T_ref)**1.5 * (T_ref + S) / (T_amb_k + S)  # Pa·s
    
    return rho, mu
    
def get_h_a_windy(T_amb_c, v, a):
    T_amb_k = T_amb_c + 273.15
    
    rho, mu = get_air_properties(T_amb_c)
      
    # Calculate Re at length L (device width)
    Re_L = rho * v * a / mu
    if Re_L >= 5e5:
        print(f"Warning: Reynolds number ({Re_L:.2e}) exceeds laminar flow limit (5e5).")
        print(f"The correlation may not be accurate for turbulent flow.")

    # Calculate average convection coefficient 
    h_a = 2 * 0.453 * params["Pr"]**(1/3) * (rho * v / mu)**0.5 * params["k_air"] * a**(-0.5)

    return h_a

def get_h_a_windless(T_amb_c, a):
    T_amb_k = T_amb_c + 273.15
    T_abs_k = 273.15 + 60              # assume 60C for the solar absorber 
    T_avg_k = (T_amb_k + T_abs_k) / 2  # Film temperature for properties

    rho, mu = get_air_properties(T_avg_k - 273.15)

    # Calculate kinematic viscosity
    nu = mu / rho  # m²/s

    # Gravitational acceleration
    g = 9.81  # m/s²

    # Coefficient of volume expansion for ideal gas: β = 1/T
    beta = 1 / T_avg_k  # 1/K
    
    # Characteristic length for horizontal plate
    l_c = a**2/(4*a)
    
    # Calculate Rayleigh number 
    Ra = (g * beta * abs(T_abs_k - T_amb_k) * l_c**3 * params["Pr"]) / (nu**2)

    # Check if Ra is in valid range
    if Ra < 1e4:
        print(f"Warning: Rayleigh number ({Ra:.2e}) is below the correlation range (10^4 to 10^7).")
        print(f"Natural convection may be negligible.")
    elif Ra > 1e7:
        print(f"Warning: Rayleigh number ({Ra:.2e}) exceeds the correlation range (10^4 to 10^7).")
        print(f"The correlation may not be accurate for turbulent natural convection.")

    # Calculate natural convection coefficient (Nu = h_a * k_air/l_c = 0.54 * Ra^0.25)
    h_a = 0.54 * Ra**0.25 * params["k_air"] / l_c

    return h_a

# %%
# --- Load and process spectral data ---

try:
    file_path = os.path.join("data", "PMMA_3mm_transmittance.csv")

    column_names = ['wavelength_um', 'transmittance_material', 'transmittance_atm']
    pmma_data = pd.read_csv(file_path, skiprows=1, names=column_names)

    for col in column_names:
        pmma_data[col] = pd.to_numeric(pmma_data[col])

    pmma_data['wavelength_m'] = pmma_data['wavelength_um'] * 1e-6

    pmma_data['delta_lambda'] = pmma_data['wavelength_m'].diff().bfill()

    print("Successfully loaded and processed PMMA and atmospheric spectral data.")
    
except Exception as e:
    print(f"Error loading or processing PMMA_3mm_transmittance.csv: {e}")
    pmma_data = None
# Out:
# Successfully loaded and processed PMMA and atmospheric spectral data.

# %%
# --- Helper Functions ---
def planck_law(wav, T):
    """Calculates spectral radiance using Planck's Law."""
    C1 = 3.7418e-16
    C2 = 1.4388e-2
    return (C1 / (wav**5)) / (np.exp(C2 / (wav * T)) - 1)

def calculate_q_rad(T_f_k, p, spectral_data):
    """
    Calculates q_rad by integrating Planck's law over the spectral data.
    """
    if spectral_data is None: return 0
    T_amb_k = p["T_amb_c"] + 273.15
    
    E_f = planck_law(spectral_data['wavelength_m'], T_f_k)
    E_amb = planck_law(spectral_data['wavelength_m'], T_amb_k)

    tr = spectral_data['transmittance_material']
    delta_lambda = spectral_data['delta_lambda']
    epsilon = p["epsilon"]

    if p["condition"] == 'indoor':
        integrand = tr * epsilon * (E_f - E_amb) * delta_lambda
        q_rad = integrand.sum()
    else: # outdoor
        trans_atm = spectral_data['transmittance_atm']
        integrand = tr * epsilon * (E_f - (1 - trans_atm) * E_amb) * delta_lambda
        q_rad = integrand.sum()       
    return q_rad
    
def calculate_saturation_concentration(T_k, activity=1.0):
    """
    Calculates water vapor saturation concentration (mol/m³) at a given temperature,
    using August-Roche-Magnus formula, adjusted for the solution's activity.
    """
    T_c = T_k - 273.15
    # P_sat_pure = 610.94 * np.exp((17.625 * T_c) / (T_c + 243.04)) # August-Roche-Magnus formula
    P_sat_pure = 133.32 * 10**8.07131 / 10**(1730.63/(T_c + 233.426)) # Antoine equation
    P_sat_solution = P_sat_pure * activity
    return P_sat_solution / (params["R_gas"] * T_k)

def find_top_surface_temp(T_f_k, p):
    T_amb_k = p["T_amb_c"] + 273.15
    def top_surface_balance(T_top_k):
        q_cond_up = (T_f_k - T_top_k) / ((p["t_pmma"] / p["k_pmma"]) + (p["t_air"]/p["k_air"]))
        q_conv_out = p["h_a"] * (T_top_k - T_amb_k)
        if p["condition"] == 'indoor':
            q_rad_out = 0.99 * p["sigma"] * (T_top_k**4 - T_amb_k**4)
        if p["condition"] == 'outdoor':
            q_rad_out = (0.0335*(T_top_k-273.15)**2 + 3.0848*(T_top_k-273.15) + 90.8569) * (0.99 / 0.95)
        return q_cond_up - (q_conv_out + q_rad_out)
    initial_guess_T_top = (T_f_k + T_amb_k) / 2
    return fsolve(top_surface_balance, initial_guess_T_top)[0]

def solve_stage_backward(q_out, T_b_c, p, is_first_stage=False):
    """
    Solves a single stage backward to find the input heat and front wall temp.
    """
    T_b_k = T_b_c + 273.15

    def find_Tf_from_q_out(T_f_c, q_out_target, T_b_k, p):
        T_f_k = T_f_c + 273.15
        q_cond = p["k_air"] * (T_f_k - T_b_k) / p["b"]
        q_rad_int = p["epsilon"] * p["sigma"]*(T_f_k**4 - T_b_k**4)
        # Use activity=0.98 for evaporating seawater at the front wall
        c_f = calculate_saturation_concentration(T_f_k, activity=0.98)
        # Use activity=1.0 for condensing pure water at the back wall
        c_b = calculate_saturation_concentration(T_b_k, activity=1.0)
        J_evap_molar = p["D_a"] * (c_f - c_b) / p["b"]
        q_evap = (J_evap_molar * p["M_water"]) * p["h_fg"]
        return (q_cond + q_evap + q_rad_int) - q_out_target

    initial_guess_T_f = T_b_c + 5.0
    T_f_c_solved = fsolve(find_Tf_from_q_out, initial_guess_T_f, args=(q_out, T_b_k, p))[0]
    T_f_k_solved = T_f_c_solved + 273.15

    T_top_k_solved = find_top_surface_temp(T_f_k_solved, p)
    T_top_c_solved = T_top_k_solved - 273.15

    T_amb_k = p["T_amb_c"] + 273.15
    R_side = (1 / p["h_a"]) + (p["t_ins"] / p["k_ins"])
    T_avg_side_k = (T_f_k_solved + T_b_k) / 2
    q_side_per_front_area = (T_avg_side_k - T_amb_k) / R_side * (4 * p["b"] / p["a"])

    q_in = q_out + q_side_per_front_area

    if is_first_stage:
        q_rad = calculate_q_rad(T_f_k_solved, p, pmma_data)
 
        R_top = (1 / p["h_a"]) + (p["t_pmma"] / p["k_pmma"]) + (p["t_air"]/p["k_air"])
        q_cond_up = (T_f_k_solved - T_amb_k) / R_top
        R_top_side = (1 / p["h_a"]) + (p["t_ins"] / p["k_ins"])
        q_cond_side = (((T_f_k_solved + T_amb_k) / 2) - T_amb_k) / R_top_side * (4 * (p["t_air"] + p["t_pmma"]) / p["a"])
            

        q_in += q_rad + q_cond_up + q_cond_side

    return q_in, T_f_c_solved, T_top_c_solved

# %%
# --- Main Multi-Stage Simulation ---
def run_multistage_simulation(n_stages, params):

    q_out_n = params["q_sun"] * params["ref_abs"] * params["Tr"]
    tolerance = 0.1
    max_iterations = 100
    stage_data = []

    print(f"--- Running Multi-Stage Simulation for {n_stages} Stages ---\n")

    for iteration in range(max_iterations):
        current_stage_data = []
        q_out_current = q_out_n
        T_b_current_c = params["T_b_c"]

        for i in range(n_stages, 0, -1):
            is_first = (i == 1)
            q_in_current, T_f_current_c, T_top_current_c = solve_stage_backward(q_out_current, T_b_current_c, params, is_first_stage=is_first)
            current_stage_data.append({"stage": i, "T_f": T_f_current_c, "T_b": T_b_current_c, "T_top": T_top_current_c})
            q_out_current = q_in_current
            T_b_current_c = T_f_current_c

        current_stage_data.reverse()
        q_in_1_calculated = q_out_current # This is now q_in of the first stage
        error = abs(q_in_1_calculated - params["q_sun"]* params["ref_abs"] * params["Tr"])

        print(f"Iteration {iteration + 1}: Calculated q_in,1 = {q_in_1_calculated:.2f} W/m^2, Error = {error:.2f} W/m^2")

        if error < tolerance:
            print("\nConvergence reached!")
            stage_data = current_stage_data
            break

        scaling_factor = params["q_sun"]* params["ref_abs"] * params["Tr"] / q_in_1_calculated
        q_out_n *= scaling_factor
    else:
        print("\nWarning: Maximum iterations reached without convergence.")
        stage_data = current_stage_data

    # --- Final Calculations and Output ---
    print("\n--- Per-Stage Detailed Results ---")
    total_evap_heat = 0
    for data in stage_data:
        T_f_c = data["T_f"]
        T_b_c = data["T_b"]
        T_f_k = T_f_c + 273.15
        T_b_k = T_b_c + 273.15

        # Calculate vapor flux for this stage 
        c_f = calculate_saturation_concentration(T_f_k, activity=0.98)
        c_b = calculate_saturation_concentration(T_b_k, activity=1.0)
        J_evap_molar = params["D_a"] * (c_f - c_b) / params["b"]
        J_evap_mass = J_evap_molar * params["M_water"]
        J_evap_kg_hr = J_evap_mass * 3600
        
        # Calculate heat carried by evaporation
        q_evap = J_evap_mass * params["h_fg"]
        total_evap_heat += q_evap

        if data['stage'] == 1:
            T_top_c = data["T_top"]
            top_temp_str = f"| Top Surface Temp: {T_top_c:.2f}°C "
        else: top_temp_str = ""

        print(f"  Stage {data['stage']}: Evap Temp: {data['T_f']:.2f}°C | Condensation Temp: {data['T_b']:.2f}°C | Vapor Flux: {J_evap_kg_hr:.2f} kg/m²/hr")

    print(f"\nTop Surface Temp: { T_top_c:.2f}°C ")
    print("\n--- Overall Performance ---")
    eta_tot = total_evap_heat / params["q_sun"]
    total_vapor_flux_kg_hr = (total_evap_heat / params["h_fg"]) * 3600
    print(f"Total Vapor Mass Flux: {total_vapor_flux_kg_hr:.2f} kg/m²/hr")
    print(f"Total Efficiency (eta_tot): {eta_tot * 100:.2f}%")

    results = {
        "water productivity (kg/m2/hr)": round(total_vapor_flux_kg_hr, 2),
        "total efficiency (%)": round(eta_tot * 100, 2),
        "absorber temp (C)": round(stage_data[0]['T_f'], 2) if stage_data else None,
        "top surface temp (C)": round(stage_data[0]['T_top'], 2) if stage_data else None,
    }
    return results

# %% [markdown]
# # Simulation Cases in Figure 3

# %%
simulation_cases_Fig3 = [
    {
        "name": "Indoor, windless", #Figure 3b
        "condition": 'indoor',
        "v": 0,
        "a": 0.05,
    },    
    {
        "name": "Indoor, 2 m/s wind", #Figure 3b
        "condition": 'indoor',
        "v": 2.0,
    },
    {
        "name": "Indoor, 4 m/s wind", #Figure 3b
        "condition": 'indoor',
        "v": 4.0,
    },
    {
        "name": "Indoor, 6 m/s wind", #Figure 3b
        "condition": 'indoor',
        "v": 6.0,
    },   
    {
        "name": "Outdoor, windless", #Figure 3c
        "condition": "outdoor",
        "v": 0,
    },       
    {
        "name": "Outdoor, 2 m/s wind", #Figure 3c
        "condition": "outdoor",
        "v": 2.0,
    },      
    {
        "name": "Outdoor, windless, 20°C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 25,
        "T_amb_c": 20,
        "v": 0, 
    },
    {
        "name": "Outdoor, windless, 30°C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 35,
        "T_amb_c": 30,
        "v": 0, 
    },
    {
        "name": "Outdoor, windless, 35°C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 40,
        "T_amb_c": 35,
        "v": 0,
    },
    {
        "name": "Outdoor, windless, 40°C ambient temperature", #Figure 3e
        "condition": "outdoor",
        "T_b_c": 45,
        "T_amb_c": 40,
        "v": 0, 
    },    
    {
        "name": "Outdoor, 0.7 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 700, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    },
    {
        "name": "Outdoor, 0.5 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 500, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    }, 
    {
        "name": "Outdoor, 0.3 kW/m2 solar flux", #Figure 3f
        "condition": "outdoor",
        "q_sun": 300, 
        "T_b_c": 30,
        "T_amb_c": 25,
        "v": 0,
    },    
]

# %%
# --- Run All Simulation Cases in Fig 3 ---
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
if __name__ == "__main__":
    number_of_stages =  6

    all_results_data = []

    for case in simulation_cases_Fig3:
        print(f"\n========================================================")
        print(f"Running: {case['name']}")
        print(f"========================================================")

        current_params = params.copy()
        current_params.update(case)
        
        if current_params["v"] <= 0.1:  # Windless
            current_params["h_a"] = get_h_a_windless(current_params["T_amb_c"], current_params["a"])
        else:  # Windy
            current_params["h_a"] = get_h_a_windy(current_params["T_amb_c"], current_params["v"], current_params["a"])

        # Run Simulation
        output_results = run_multistage_simulation(number_of_stages, current_params)

        result_row = {"name": case["name"]}
        result_row.update(output_results)
        
        all_results_data.append(result_row)
        

    results_df = pd.DataFrame(all_results_data)

    output_filename = os.path.join("results", f"PMMA_Fig3_simulation_Fig3_summary_{timestamp}.csv")
    results_df.to_csv(output_filename, index=False)

    print(f"\n\n All Fig 3 simulations complete. Results saved to '{output_filename}'")
# Out:
# ========================================================
# Running: Indoor, windless
# ========================================================
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1189.00 W/m^2, Error = 369.66 W/m^2
# Iteration 2: Calculated q_in,1 = 873.54 W/m^2, Error = 54.20 W/m^2
# Iteration 3: Calculated q_in,1 = 828.88 W/m^2, Error = 9.53 W/m^2
# Iteration 4: Calculated q_in,1 = 821.07 W/m^2, Error = 1.73 W/m^2
# Iteration 5: Calculated q_in,1 = 819.66 W/m^2, Error = 0.31 W/m^2
# Iteration 6: Calculated q_in,1 = 819.40 W/m^2, Error = 0.06 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 68.25°C | Condensation Temp: 63.81°C | Vapor Flux: 0.84 kg/m²/hr
#   Stage 2: Evap Temp: 63.81°C | Condensation Temp: 58.96°C | Vapor Flux: 0.79 kg/m²/hr
#   Stage 3: Evap Temp: 58.96°C | Condensation Temp: 53.56°C | Vapor Flux: 0.74 kg/m²/hr
#   Stage 4: Evap Temp: 53.56°C | Condensation Temp: 47.34°C | Vapor Flux: 0.69 kg/m²/hr
#   Stage 5: Evap Temp: 47.34°C | Condensation Temp: 39.81°C | Vapor Flux: 0.65 kg/m²/hr
#   Stage 6: Evap Temp: 39.81°C | Condensation Temp: 30.00°C | Vapor Flux: 0.59 kg/m²/hr
#
# Top Surface Temp: 33.84°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.29 kg/m²/hr
# Total Efficiency (eta_tot): 280.79%
#
# ========================================================
# Running: Indoor, 2 m/s wind
# ========================================================
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1290.98 W/m^2, Error = 471.63 W/m^2
# Iteration 2: Calculated q_in,1 = 899.12 W/m^2, Error = 79.77 W/m^2
# Iteration 3: Calculated q_in,1 = 835.94 W/m^2, Error = 16.60 W/m^2
# Iteration 4: Calculated q_in,1 = 822.94 W/m^2, Error = 3.59 W/m^2
# Iteration 5: Calculated q_in,1 = 820.13 W/m^2, Error = 0.79 W/m^2
# Iteration 6: Calculated q_in,1 = 819.51 W/m^2, Error = 0.17 W/m^2
# Iteration 7: Calculated q_in,1 = 819.38 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 66.16°C | Condensation Temp: 61.74°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 2: Evap Temp: 61.74°C | Condensation Temp: 56.99°C | Vapor Flux: 0.72 kg/m²/hr
#   Stage 3: Evap Temp: 56.99°C | Condensation Temp: 51.77°C | Vapor Flux: 0.66 kg/m²/hr
#   Stage 4: Evap Temp: 51.77°C | Condensation Temp: 45.85°C | Vapor Flux: 0.61 kg/m²/hr
#   Stage 5: Evap Temp: 45.85°C | Condensation Temp: 38.86°C | Vapor Flux: 0.57 kg/m²/hr
#   Stage 6: Evap Temp: 38.86°C | Condensation Temp: 30.00°C | Vapor Flux: 0.52 kg/m²/hr
#
# Top Surface Temp: 28.79°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.86 kg/m²/hr
# Total Efficiency (eta_tot): 252.52%
#
# ========================================================
# Running: Indoor, 4 m/s wind
# ========================================================
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1306.43 W/m^2, Error = 487.09 W/m^2
# Iteration 2: Calculated q_in,1 = 903.20 W/m^2, Error = 83.86 W/m^2
# Iteration 3: Calculated q_in,1 = 837.16 W/m^2, Error = 17.82 W/m^2
# Iteration 4: Calculated q_in,1 = 823.29 W/m^2, Error = 3.95 W/m^2
# Iteration 5: Calculated q_in,1 = 820.22 W/m^2, Error = 0.88 W/m^2
# Iteration 6: Calculated q_in,1 = 819.54 W/m^2, Error = 0.20 W/m^2
# Iteration 7: Calculated q_in,1 = 819.39 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 65.85°C | Condensation Temp: 61.44°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 2: Evap Temp: 61.44°C | Condensation Temp: 56.70°C | Vapor Flux: 0.71 kg/m²/hr
#   Stage 3: Evap Temp: 56.70°C | Condensation Temp: 51.51°C | Vapor Flux: 0.65 kg/m²/hr
#   Stage 4: Evap Temp: 51.51°C | Condensation Temp: 45.64°C | Vapor Flux: 0.60 kg/m²/hr
#   Stage 5: Evap Temp: 45.64°C | Condensation Temp: 38.72°C | Vapor Flux: 0.56 kg/m²/hr
#   Stage 6: Evap Temp: 38.72°C | Condensation Temp: 30.00°C | Vapor Flux: 0.51 kg/m²/hr
#
# Top Surface Temp: 27.86°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.80 kg/m²/hr
# Total Efficiency (eta_tot): 248.56%
#
# ========================================================
# Running: Indoor, 6 m/s wind
# ========================================================
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1313.61 W/m^2, Error = 494.27 W/m^2
# Iteration 2: Calculated q_in,1 = 905.12 W/m^2, Error = 85.78 W/m^2
# Iteration 3: Calculated q_in,1 = 837.74 W/m^2, Error = 18.40 W/m^2
# Iteration 4: Calculated q_in,1 = 823.46 W/m^2, Error = 4.12 W/m^2
# Iteration 5: Calculated q_in,1 = 820.27 W/m^2, Error = 0.93 W/m^2
# Iteration 6: Calculated q_in,1 = 819.55 W/m^2, Error = 0.21 W/m^2
# Iteration 7: Calculated q_in,1 = 819.39 W/m^2, Error = 0.05 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 65.71°C | Condensation Temp: 61.30°C | Vapor Flux: 0.76 kg/m²/hr
#   Stage 2: Evap Temp: 61.30°C | Condensation Temp: 56.57°C | Vapor Flux: 0.70 kg/m²/hr
#   Stage 3: Evap Temp: 56.57°C | Condensation Temp: 51.39°C | Vapor Flux: 0.65 kg/m²/hr
#   Stage 4: Evap Temp: 51.39°C | Condensation Temp: 45.54°C | Vapor Flux: 0.60 kg/m²/hr
#   Stage 5: Evap Temp: 45.54°C | Condensation Temp: 38.66°C | Vapor Flux: 0.55 kg/m²/hr
#   Stage 6: Evap Temp: 38.66°C | Condensation Temp: 30.00°C | Vapor Flux: 0.51 kg/m²/hr
#
# Top Surface Temp: 27.40°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.77 kg/m²/hr
# Total Efficiency (eta_tot): 246.75%
#
# ========================================================
# Running: Outdoor, windless
# ========================================================
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1190.29 W/m^2, Error = 370.95 W/m^2
# Iteration 2: Calculated q_in,1 = 874.05 W/m^2, Error = 54.71 W/m^2
# Iteration 3: Calculated q_in,1 = 829.03 W/m^2, Error = 9.69 W/m^2
# Iteration 4: Calculated q_in,1 = 821.11 W/m^2, Error = 1.77 W/m^2
# Iteration 5: Calculated q_in,1 = 819.67 W/m^2, Error = 0.32 W/m^2
# Iteration 6: Calculated q_in,1 = 819.40 W/m^2, Error = 0.06 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 68.21°C | Condensation Temp: 63.77°C | Vapor Flux: 0.83 kg/m²/hr
#   Stage 2: Evap Temp: 63.77°C | Condensation Temp: 58.93°C | Vapor Flux: 0.78 kg/m²/hr
#   Stage 3: Evap Temp: 58.93°C | Condensation Temp: 53.53°C | Vapor Flux: 0.74 kg/m²/hr
#   Stage 4: Evap Temp: 53.53°C | Condensation Temp: 47.31°C | Vapor Flux: 0.69 kg/m²/hr
#   Stage 5: Evap Temp: 47.31°C | Condensation Temp: 39.80°C | Vapor Flux: 0.64 kg/m²/hr
#   Stage 6: Evap Temp: 39.80°C | Condensation Temp: 30.00°C | Vapor Flux: 0.59 kg/m²/hr
#
# Top Surface Temp: 23.79°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.28 kg/m²/hr
# Total Efficiency (eta_tot): 280.23%
#
# ========================================================
# Running: Outdoor, 2 m/s wind
# ========================================================
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1292.26 W/m^2, Error = 472.92 W/m^2
# Iteration 2: Calculated q_in,1 = 899.70 W/m^2, Error = 80.36 W/m^2
# Iteration 3: Calculated q_in,1 = 836.15 W/m^2, Error = 16.81 W/m^2
# Iteration 4: Calculated q_in,1 = 823.00 W/m^2, Error = 3.66 W/m^2
# Iteration 5: Calculated q_in,1 = 820.15 W/m^2, Error = 0.80 W/m^2
# Iteration 6: Calculated q_in,1 = 819.52 W/m^2, Error = 0.18 W/m^2
# Iteration 7: Calculated q_in,1 = 819.38 W/m^2, Error = 0.04 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 66.12°C | Condensation Temp: 61.71°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 2: Evap Temp: 61.71°C | Condensation Temp: 56.96°C | Vapor Flux: 0.71 kg/m²/hr
#   Stage 3: Evap Temp: 56.96°C | Condensation Temp: 51.74°C | Vapor Flux: 0.66 kg/m²/hr
#   Stage 4: Evap Temp: 51.74°C | Condensation Temp: 45.83°C | Vapor Flux: 0.61 kg/m²/hr
#   Stage 5: Evap Temp: 45.83°C | Condensation Temp: 38.84°C | Vapor Flux: 0.57 kg/m²/hr
#   Stage 6: Evap Temp: 38.84°C | Condensation Temp: 30.00°C | Vapor Flux: 0.52 kg/m²/hr
#
# Top Surface Temp: 24.28°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 3.85 kg/m²/hr
# Total Efficiency (eta_tot): 252.00%
#
# ========================================================
# Running: Outdoor, windless, 20°C ambient temperature
# ========================================================
# Warning: Rayleigh number (6.07e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1225.00 W/m^2, Error = 405.65 W/m^2
# Iteration 2: Calculated q_in,1 = 884.45 W/m^2, Error = 65.10 W/m^2
# Iteration 3: Calculated q_in,1 = 831.97 W/m^2, Error = 12.63 W/m^2
# Iteration 4: Calculated q_in,1 = 821.88 W/m^2, Error = 2.54 W/m^2
# Iteration 5: Calculated q_in,1 = 819.86 W/m^2, Error = 0.51 W/m^2
# Iteration 6: Calculated q_in,1 = 819.45 W/m^2, Error = 0.10 W/m^2
# Iteration 7: Calculated q_in,1 = 819.36 W/m^2, Error = 0.02 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 65.94°C | Condensation Temp: 61.31°C | Vapor Flux: 0.81 kg/m²/hr
#   Stage 2: Evap Temp: 61.31°C | Condensation Temp: 56.24°C | Vapor Flux: 0.75 kg/m²/hr
#   Stage 3: Evap Temp: 56.24°C | Condensation Temp: 50.56°C | Vapor Flux: 0.70 kg/m²/hr
#   Stage 4: Evap Temp: 50.56°C | Condensation Temp: 43.95°C | Vapor Flux: 0.65 kg/m²/hr
#   Stage 5: Evap Temp: 43.95°C | Condensation Temp: 35.84°C | Vapor Flux: 0.60 kg/m²/hr
#   Stage 6: Evap Temp: 35.84°C | Condensation Temp: 25.00°C | Vapor Flux: 0.54 kg/m²/hr
#
# Top Surface Temp: 20.68°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.05 kg/m²/hr
# Total Efficiency (eta_tot): 265.23%
#
# ========================================================
# Running: Outdoor, windless, 30°C ambient temperature
# ========================================================
# Warning: Rayleigh number (4.24e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1157.28 W/m^2, Error = 337.93 W/m^2
# Iteration 2: Calculated q_in,1 = 865.03 W/m^2, Error = 45.68 W/m^2
# Iteration 3: Calculated q_in,1 = 826.71 W/m^2, Error = 7.37 W/m^2
# Iteration 4: Calculated q_in,1 = 820.56 W/m^2, Error = 1.22 W/m^2
# Iteration 5: Calculated q_in,1 = 819.55 W/m^2, Error = 0.20 W/m^2
# Iteration 6: Calculated q_in,1 = 819.38 W/m^2, Error = 0.03 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 70.55°C | Condensation Temp: 66.31°C | Vapor Flux: 0.86 kg/m²/hr
#   Stage 2: Evap Temp: 66.31°C | Condensation Temp: 61.70°C | Vapor Flux: 0.81 kg/m²/hr
#   Stage 3: Evap Temp: 61.70°C | Condensation Temp: 56.59°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 4: Evap Temp: 56.59°C | Condensation Temp: 50.76°C | Vapor Flux: 0.73 kg/m²/hr
#   Stage 5: Evap Temp: 50.76°C | Condensation Temp: 43.81°C | Vapor Flux: 0.69 kg/m²/hr
#   Stage 6: Evap Temp: 43.81°C | Condensation Temp: 35.00°C | Vapor Flux: 0.64 kg/m²/hr
#
# Top Surface Temp: 26.80°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.50 kg/m²/hr
# Total Efficiency (eta_tot): 294.87%
#
# ========================================================
# Running: Outdoor, windless, 35°C ambient temperature
# ========================================================
# Warning: Rayleigh number (3.41e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1125.94 W/m^2, Error = 306.60 W/m^2
# Iteration 2: Calculated q_in,1 = 857.26 W/m^2, Error = 37.92 W/m^2
# Iteration 3: Calculated q_in,1 = 824.90 W/m^2, Error = 5.56 W/m^2
# Iteration 4: Calculated q_in,1 = 820.18 W/m^2, Error = 0.83 W/m^2
# Iteration 5: Calculated q_in,1 = 819.47 W/m^2, Error = 0.13 W/m^2
# Iteration 6: Calculated q_in,1 = 819.36 W/m^2, Error = 0.02 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 73.00°C | Condensation Temp: 68.95°C | Vapor Flux: 0.89 kg/m²/hr
#   Stage 2: Evap Temp: 68.95°C | Condensation Temp: 64.58°C | Vapor Flux: 0.84 kg/m²/hr
#   Stage 3: Evap Temp: 64.58°C | Condensation Temp: 59.75°C | Vapor Flux: 0.80 kg/m²/hr
#   Stage 4: Evap Temp: 59.75°C | Condensation Temp: 54.30°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 5: Evap Temp: 54.30°C | Condensation Temp: 47.91°C | Vapor Flux: 0.73 kg/m²/hr
#   Stage 6: Evap Temp: 47.91°C | Condensation Temp: 40.00°C | Vapor Flux: 0.69 kg/m²/hr
#
# Top Surface Temp: 29.67°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.72 kg/m²/hr
# Total Efficiency (eta_tot): 309.13%
#
# ========================================================
# Running: Outdoor, windless, 40°C ambient temperature
# ========================================================
# Warning: Rayleigh number (2.63e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 1096.16 W/m^2, Error = 276.82 W/m^2
# Iteration 2: Calculated q_in,1 = 850.62 W/m^2, Error = 31.28 W/m^2
# Iteration 3: Calculated q_in,1 = 823.50 W/m^2, Error = 4.16 W/m^2
# Iteration 4: Calculated q_in,1 = 819.91 W/m^2, Error = 0.56 W/m^2
# Iteration 5: Calculated q_in,1 = 819.42 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 75.57°C | Condensation Temp: 71.72°C | Vapor Flux: 0.91 kg/m²/hr
#   Stage 2: Evap Temp: 71.72°C | Condensation Temp: 67.57°C | Vapor Flux: 0.87 kg/m²/hr
#   Stage 3: Evap Temp: 67.57°C | Condensation Temp: 63.03°C | Vapor Flux: 0.84 kg/m²/hr
#   Stage 4: Evap Temp: 63.03°C | Condensation Temp: 57.95°C | Vapor Flux: 0.80 kg/m²/hr
#   Stage 5: Evap Temp: 57.95°C | Condensation Temp: 52.08°C | Vapor Flux: 0.77 kg/m²/hr
#   Stage 6: Evap Temp: 52.08°C | Condensation Temp: 45.00°C | Vapor Flux: 0.74 kg/m²/hr
#
# Top Surface Temp: 32.41°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 4.93 kg/m²/hr
# Total Efficiency (eta_tot): 323.02%
#
# ========================================================
# Running: Outdoor, 0.7 kW/m2 solar flux
# ========================================================
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 886.16 W/m^2, Error = 312.62 W/m^2
# Iteration 2: Calculated q_in,1 = 622.70 W/m^2, Error = 49.16 W/m^2
# Iteration 3: Calculated q_in,1 = 583.08 W/m^2, Error = 9.54 W/m^2
# Iteration 4: Calculated q_in,1 = 575.46 W/m^2, Error = 1.92 W/m^2
# Iteration 5: Calculated q_in,1 = 573.93 W/m^2, Error = 0.39 W/m^2
# Iteration 6: Calculated q_in,1 = 573.62 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 59.74°C | Condensation Temp: 55.88°C | Vapor Flux: 0.54 kg/m²/hr
#   Stage 2: Evap Temp: 55.88°C | Condensation Temp: 51.76°C | Vapor Flux: 0.50 kg/m²/hr
#   Stage 3: Evap Temp: 51.76°C | Condensation Temp: 47.31°C | Vapor Flux: 0.46 kg/m²/hr
#   Stage 4: Evap Temp: 47.31°C | Condensation Temp: 42.37°C | Vapor Flux: 0.43 kg/m²/hr
#   Stage 5: Evap Temp: 42.37°C | Condensation Temp: 36.74°C | Vapor Flux: 0.40 kg/m²/hr
#   Stage 6: Evap Temp: 36.74°C | Condensation Temp: 30.00°C | Vapor Flux: 0.37 kg/m²/hr
#
# Top Surface Temp: 21.93°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 2.70 kg/m²/hr
# Total Efficiency (eta_tot): 252.77%
#
# ========================================================
# Running: Outdoor, 0.5 kW/m2 solar flux
# ========================================================
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 674.05 W/m^2, Error = 264.37 W/m^2
# Iteration 2: Calculated q_in,1 = 454.04 W/m^2, Error = 44.37 W/m^2
# Iteration 3: Calculated q_in,1 = 419.22 W/m^2, Error = 9.55 W/m^2
# Iteration 4: Calculated q_in,1 = 411.83 W/m^2, Error = 2.16 W/m^2
# Iteration 5: Calculated q_in,1 = 410.17 W/m^2, Error = 0.49 W/m^2
# Iteration 6: Calculated q_in,1 = 409.78 W/m^2, Error = 0.11 W/m^2
# Iteration 7: Calculated q_in,1 = 409.70 W/m^2, Error = 0.03 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 52.89°C | Condensation Temp: 49.60°C | Vapor Flux: 0.35 kg/m²/hr
#   Stage 2: Evap Temp: 49.60°C | Condensation Temp: 46.18°C | Vapor Flux: 0.32 kg/m²/hr
#   Stage 3: Evap Temp: 46.18°C | Condensation Temp: 42.60°C | Vapor Flux: 0.30 kg/m²/hr
#   Stage 4: Evap Temp: 42.60°C | Condensation Temp: 38.79°C | Vapor Flux: 0.27 kg/m²/hr
#   Stage 5: Evap Temp: 38.79°C | Condensation Temp: 34.64°C | Vapor Flux: 0.25 kg/m²/hr
#   Stage 6: Evap Temp: 34.64°C | Condensation Temp: 30.00°C | Vapor Flux: 0.24 kg/m²/hr
#
# Top Surface Temp: 20.41°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 1.74 kg/m²/hr
# Total Efficiency (eta_tot): 227.22%
#
# ========================================================
# Running: Outdoor, 0.3 kW/m2 solar flux
# ========================================================
# Warning: Rayleigh number (5.12e+03) is below the correlation range (10^4 to 10^7).
# Natural convection may be negligible.
# --- Running Multi-Stage Simulation for 6 Stages ---
#
# Iteration 1: Calculated q_in,1 = 449.51 W/m^2, Error = 203.70 W/m^2
# Iteration 2: Calculated q_in,1 = 285.03 W/m^2, Error = 39.23 W/m^2
# Iteration 3: Calculated q_in,1 = 256.32 W/m^2, Error = 10.51 W/m^2
# Iteration 4: Calculated q_in,1 = 248.86 W/m^2, Error = 3.05 W/m^2
# Iteration 5: Calculated q_in,1 = 246.71 W/m^2, Error = 0.91 W/m^2
# Iteration 6: Calculated q_in,1 = 246.07 W/m^2, Error = 0.27 W/m^2
# Iteration 7: Calculated q_in,1 = 245.88 W/m^2, Error = 0.08 W/m^2
#
# Convergence reached!
#
# --- Per-Stage Detailed Results ---
#   Stage 1: Evap Temp: 44.65°C | Condensation Temp: 42.22°C | Vapor Flux: 0.18 kg/m²/hr
#   Stage 2: Evap Temp: 42.22°C | Condensation Temp: 39.82°C | Vapor Flux: 0.16 kg/m²/hr
#   Stage 3: Evap Temp: 39.82°C | Condensation Temp: 37.41°C | Vapor Flux: 0.15 kg/m²/hr
#   Stage 4: Evap Temp: 37.41°C | Condensation Temp: 35.00°C | Vapor Flux: 0.13 kg/m²/hr
#   Stage 5: Evap Temp: 35.00°C | Condensation Temp: 32.54°C | Vapor Flux: 0.12 kg/m²/hr
#   Stage 6: Evap Temp: 32.54°C | Condensation Temp: 30.00°C | Vapor Flux: 0.11 kg/m²/hr
#
# Top Surface Temp: 18.57°C
#
# --- Overall Performance ---
# Total Vapor Mass Flux: 0.86 kg/m²/hr
# Total Efficiency (eta_tot): 188.39%
#
#
#  All Fig 3 simulations complete. Results saved to 'results\PMMA_Fig3_simulation_Fig3_summary_20251225_200037.csv'
